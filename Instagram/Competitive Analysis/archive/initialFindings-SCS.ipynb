# %% [markdown]
# # Import & Read CSVs #

# %%
import pandas as pd
pd.set_option('max_row', None)
pd.set_option('max_columns', None)

import numpy as np
from scipy import stats

from tabulate import tabulate
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import time, urllib.request
import requests

import re
from collections import Counter

# %%
followerDF = pd.read_csv("./SCS/SCS_Followers.csv")
followingDF = pd.read_csv("./SCS/SCS_Followings.csv")
postDF = pd.read_csv("./SCS/allposts.csv")
# profileDF = pd.read_csv("./SCS/SCS_Followers.csv")
taggedpostDF = pd.read_csv("./SCS/taggedposts.csv")
commentDF = pd.read_csv("./SCS/comments.csv")

# %%
display(followerDF.head())
# Out:
#                                  profileUrl        username  \
# 0     https://www.instagram.com/ngsb5218_10     ngsb5218_10
# 1     https://www.instagram.com/1027jun1999     1027jun1999
# 2  https://www.instagram.com/justcuzyouknow  justcuzyouknow
# 3   https://www.instagram.com/a.k.s.h.a.y.a   a.k.s.h.a.y.a
# 4          https://www.instagram.com/jyxvox          jyxvox
#
#                 fullName                                             imgUrl  \
# 0           Lim Yue Hang  https://scontent-lga3-1.cdninstagram.com/v/t51...
# 1            1027jun1999  https://scontent-lga3-1.cdninstagram.com/v/t51...
# 2  the1month1reply@1%one  https://scontent-lga3-1.cdninstagram.com/v/t51...
# 3              🍒Akshaya🍒  https://scontent-lga3-1.cdninstagram.com/v/t51...
# 4          Letter J & Y.  https://scontent-lga3-1.cdninstagram.com/v/t51...
#
#             id  isPrivate  isVerified  \
# 0   4338409078      False       False
# 1  39128500724       True       False
# 2  48547816958       True       False
# 3   1180206718       True       False
# 4  45620521252       True       False
#
#                                       query                 timestamp
# 0  https://www.instagram.com/sgchildrensoc/  2022-03-22T06:00:30.350Z
# 1  https://www.instagram.com/sgchildrensoc/  2022-03-22T06:00:30.350Z
# 2  https://www.instagram.com/sgchildrensoc/  2022-03-22T06:00:30.350Z
# 3  https://www.instagram.com/sgchildrensoc/  2022-03-22T06:00:30.350Z
# 4  https://www.instagram.com/sgchildrensoc/  2022-03-22T06:00:30.350Z

# %%
display(followingDF.head())
# Out:
#                              profileUrl    username                  fullName  \
# 0  https://www.instagram.com/_iamstanz_  _iamstanz_               Stanley Tan
# 1     https://www.instagram.com/pandadl     pandadl             Deryk | 데릭
# 2    https://www.instagram.com/vox.44cc    vox.44cc  VOX @ Children’s Society
# 3    https://www.instagram.com/jremytay    jremytay             J to the Remy
# 4   https://www.instagram.com/erviano__   erviano__                 Ervin Lim
#
#                                               imgUrl          id  isPrivate  \
# 0  https://scontent-yyz1-1.cdninstagram.com/v/t51...  1930845621       True
# 1  https://scontent-yyz1-1.cdninstagram.com/v/t51...    39223755      False
# 2  https://scontent-yyz1-1.cdninstagram.com/v/t51...  1834768088      False
# 3  https://scontent-yyz1-1.cdninstagram.com/v/t51...   194190647       True
# 4  https://scontent-yyz1-1.cdninstagram.com/v/t51...   453618877      False
#
#    isVerified                                     query  \
# 0       False  https://www.instagram.com/sgchildrensoc/
# 1       False  https://www.instagram.com/sgchildrensoc/
# 2       False  https://www.instagram.com/sgchildrensoc/
# 3       False  https://www.instagram.com/sgchildrensoc/
# 4       False  https://www.instagram.com/sgchildrensoc/
#
#                   timestamp
# 0  2022-03-23T02:50:05.045Z
# 1  2022-03-23T02:50:05.045Z
# 2  2022-03-23T02:50:05.045Z
# 3  2022-03-23T02:50:05.045Z
# 4  2022-03-23T02:50:05.045Z

# %%
display(postDF.head())
# Out:
#                                     postUrl  \
# 0  https://www.instagram.com/p/CbZBDq6rRnv/
# 1  https://www.instagram.com/p/CbW1HoSrDt0/
# 2  https://www.instagram.com/p/CbHbKk2rDGb/
# 3  https://www.instagram.com/p/CbHbKk2rDGb/
# 4  https://www.instagram.com/p/CbHbKk2rDGb/
#
#                                          description  commentCount  likeCount  \
# 0  Today is World Water Day. To raise awareness a...             0         12
# 1  “Hello, I’m Tinkle Friend! What would you like...             0         36
# 2  It is World Social Work Day today! We invited ...             1         73
# 3  It is World Social Work Day today! We invited ...             1         73
# 4  It is World Social Work Day today! We invited ...             1         73
#
#                     pubDate likedByViewer isSidecar   type  \
# 0  2022-03-22T03:23:22.000Z         False     False  Photo
# 1  2022-03-21T07:00:34.000Z         False     False  Photo
# 2  2022-03-15T07:25:10.000Z         False      True  Photo
# 3  2022-03-15T07:25:10.000Z         False      True  Photo
# 4  2022-03-15T07:25:10.000Z         False      True  Photo
#
#                                 profileUrl       username  \
# 0  https://www.instagram.com/sgchildrensoc  sgchildrensoc
# 1  https://www.instagram.com/sgchildrensoc  sgchildrensoc
# 2  https://www.instagram.com/sgchildrensoc  sgchildrensoc
# 3  https://www.instagram.com/sgchildrensoc  sgchildrensoc
# 4  https://www.instagram.com/sgchildrensoc  sgchildrensoc
#
#                        fullName  \
# 0  Singapore Children's Society
# 1  Singapore Children's Society
# 2  Singapore Children's Society
# 3  Singapore Children's Society
# 4  Singapore Children's Society
#
#                                               imgUrl  \
# 0  https://scontent-iad3-1.cdninstagram.com/v/t51...
# 1  https://scontent-iad3-1.cdninstagram.com/v/t51...
# 2  https://scontent-iad3-1.cdninstagram.com/v/t51...
# 3  https://scontent-iad3-1.cdninstagram.com/v/t51...
# 4  https://scontent-iad3-1.cdninstagram.com/v/t51...
#
#                            postId                 timestamp  \
# 0  2799273293673994735_1646646616  2022-03-22T04:33:24.708Z
# 1  2798657839221717876_1646646616  2022-03-22T04:33:24.880Z
# 2  2794321564180363644_1646646616  2022-03-22T04:33:25.099Z
# 3  2794321564197117970_1646646616  2022-03-22T04:33:25.099Z
# 4  2794321564171842147_1646646616  2022-03-22T04:33:25.099Z
#
#                                       query videoUrl  viewCount  \
# 0  https://www.instagram.com/sgchildrensoc/      NaN        NaN
# 1  https://www.instagram.com/sgchildrensoc/      NaN        NaN
# 2  https://www.instagram.com/sgchildrensoc/      NaN        NaN
# 3  https://www.instagram.com/sgchildrensoc/      NaN        NaN
# 4  https://www.instagram.com/sgchildrensoc/      NaN        NaN
#
#   taggedFullName1 taggedUsername1 taggedFullName2 taggedUsername2  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#   taggedFullName3 taggedUsername3 taggedFullName4 taggedUsername4 location  \
# 0             NaN             NaN             NaN             NaN      NaN
# 1             NaN             NaN             NaN             NaN      NaN
# 2             NaN             NaN             NaN             NaN      NaN
# 3             NaN             NaN             NaN             NaN      NaN
# 4             NaN             NaN             NaN             NaN      NaN
#
#    locationId
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
display(taggedpostDF.head())
# Out:
#                                     postUrl  \
# 0  https://www.instagram.com/p/CZLsqK4PuYE/
# 1  https://www.instagram.com/p/CZYDGVOvc0K/
# 2  https://www.instagram.com/p/CZQjWP4I_Ry/
# 3  https://www.instagram.com/p/CZOmi9qvOot/
# 4  https://www.instagram.com/p/CZJUR30vrpN/
#
#                                          profileUrl                username  \
# 0     https://www.instagram.com/daughtersoftomorrow     daughtersoftomorrow
# 1            https://www.instagram.com/zillearnplus            zillearnplus
# 2  https://www.instagram.com/pooja.agarwal.16503323  pooja.agarwal.16503323
# 3          https://www.instagram.com/annticing_bake          annticing_bake
# 4            https://www.instagram.com/tfeatkitchen            tfeatkitchen
#
#    likeCount  commentCount                                            caption  \
# 0         23             0                                                NaN
# 1          6             0  Photo shared by ZilLearn Plus on January 30, 2...
# 2         13             4                                                NaN
# 3         18             0                                                NaN
# 4        112            24                                                NaN
#
#                     pubDate  \
# 0  2022-01-26T06:12:12.000Z
# 1  2022-01-31T01:19:10.000Z
# 2  2022-01-28T03:33:20.000Z
# 3  2022-01-27T09:16:31.000Z
# 4  2022-01-25T08:00:41.000Z
#
#                                          description  \
# 0  🗣 Open for applications 🗣\n\nAre you working i...
# 1  Ang paos aren't the only gifts you can give th...
# 2                                                NaN
# 3  Finally done with all the bakes for customers,...
# 4  Lap Mei Fun aka 腊味饭\n.\nThis is one of my prou...
#
#                                     location    locationId   type  \
# 0  Singapore / Singapura / 新加坡 / சிங்கப்பூர்  1.140693e+14  Photo
# 1                                        NaN           NaN  Photo
# 2                     Singapore, City. Asia.  6.298551e+08  Video
# 3  Singapore / Singapura / 新加坡 / சிங்கப்பூர்  1.140693e+14  Photo
# 4                                        NaN           NaN  Photo
#
#                 taggedFullName1           taggedUsername1  \
# 0                         SINDA                   mysinda
# 1   New Life Community Services  newlifecommunityservices
# 2    Public Libraries Singapore           publiclibrarysg
# 3  Singapore Children's Society             sgchildrensoc
# 4  Singapore Children's Society             sgchildrensoc
#
#                taggedFullName2            taggedUsername2  \
# 0  Thye Hua Kwan Moral Society                     thk360
# 1           The Salvation Army           salvationarmyihq
# 2    Kidsstoppress | Parenting              kidsstoppress
# 3                       YoRipe                helloyoripe
# 4          Golden Bridge Foods  goldenbridgefoodsofficial
#
#                 taggedFullName3         taggedUsername3  \
# 0      TOUCH Community Services  touchcommunityservices
# 1  Singapore Children's Society           sgchildrensoc
# 2      Usborne Children's Books           usborne_books
# 3                           NaN                     NaN
# 4                        YoRipe             helloyoripe
#
#                 taggedFullName4 taggedUsername4             taggedFullName5  \
# 0  Singapore Children's Society   sgchildrensoc  Methodist Welfare Services
# 1                         MINDS         sgminds             Hagar Singapore
# 2  Singapore Children's Society   sgchildrensoc             Sharmistha Goel
# 3                           NaN             NaN                         NaN
# 4         Lee Kum Kee Singapore     leekumkeesg             HNB INFLUENCERS
#
#    taggedUsername5              taggedFullName6      taggedUsername6  \
# 0           mws.sg               PPIS Singapore               ppissg
# 1   hagarsingapore  Daughters Of Tomorrow (DOT)  daughtersoftomorrow
# 2   sharmisthagoel              The Bookoholics       thebookoholics
# 3              NaN                          NaN                  NaN
# 4  hnb_influencers                          NaN                  NaN
#
#             taggedFullName7            taggedUsername7  \
# 0  Club Rainbow (Singapore)               club.rainbow
# 1                       PSS  parkinsonsocietysingapore
# 2              Bookchor.com                  book.chor
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                  taggedFullName8    taggedUsername8           taggedFullName9  \
# 0            Serangoon Moral FSC  serangoonmoralfsc                      AWWA
# 1                           AWWA             awwasg                     SHINE
# 2  Kids activities|Homeschooling  lovethatyoucanbuy  SWADHYA PUBLISHING HOUSE
# 3                            NaN                NaN                       NaN
# 4                            NaN                NaN                       NaN
#
#             taggedUsername9             taggedFullName10 taggedUsername10  \
# 0                    awwasg                      Fei Yue        feiyue.sg
# 1                   scys.sg                 CampusImpact   campusimpactsg
# 2  swadhya_publishing_house  BookyWooky.in 📚 Kids' Books  bookywookybooks
# 3                       NaN                          NaN              NaN
# 4                       NaN                          NaN              NaN
#
#               taggedFullName11       taggedUsername11       taggedFullName12  \
# 0  South Central Community FSC                 sccfsc  Care Corner Singapore
# 1        President's Challenge  presidentschallengesg                    NaN
# 2               Shalvi Agarwal         shalvi_agarwal            salmaafreen
# 3                          NaN                    NaN                    NaN
# 4                          NaN                    NaN                    NaN
#
#   taggedUsername12          taggedFullName13        taggedUsername13  \
# 0     carecornersg  Lakeside Family Services  lakesidefamilyservices
# 1              NaN                       NaN                     NaN
# 2    salma__afreen                 BOOKTOPIA          mybooktopiauae
# 3              NaN                       NaN                     NaN
# 4              NaN                       NaN                     NaN
#
#              taggedFullName14 taggedUsername14             taggedFullName15  \
# 0  Kreta Ayer Family Services  community_kakis  New Hope Community Services
# 1                         NaN              NaN                          NaN
# 2                      Khyati     bookish.fame  Montessori Children’s House
# 3                         NaN              NaN                          NaN
# 4                         NaN              NaN                          NaN
#
#              taggedUsername15           taggedFullName16  \
# 0                     nhcs.sg  Viriya Community Services
# 1                         NaN                        NaN
# 2  montessorichildrenshousesg                Cloud Books
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#           taggedUsername16           taggedFullName17  taggedUsername17  \
# 0  viriyacommunityservices  @27 Family Service Centre             27fsc
# 1                      NaN                        NaN               NaN
# 2     cloudbookspublishing              Bookabookkids  book_a_book_kids
# 3                      NaN                        NaN               NaN
# 4                      NaN                        NaN               NaN
#
#            taggedFullName18    taggedUsername18           taggedFullName19  \
# 0  REACH Community Services  reachcommunitysvcs  Marine Parade FSC (MPFSC)
# 1                       NaN                 NaN                        NaN
# 2            Archit Agarwal     architagarwal25    Children's book express
# 3                       NaN                 NaN                        NaN
# 4                       NaN                 NaN                        NaN
#
#         taggedUsername19        taggedFullName20 taggedUsername20  \
# 0        marineparadefsc  Hougang Sheng Hong FSC           hshfsc
# 1                    NaN                     NaN              NaN
# 2  children_book_express                     NaN              NaN
# 3                    NaN                     NaN              NaN
# 4                    NaN                     NaN              NaN
#
#                                 id                 timestamp  \
# 0   2759495608640136708_3962903522  2022-03-23T02:52:37.996Z
# 1  2762972000644091146_28108432076  2022-03-23T02:52:37.996Z
# 2  2760862032082498674_33143877089  2022-03-23T02:52:37.996Z
# 3  2760313150069598765_51041512223  2022-03-23T02:52:37.996Z
# 4  2758825435843181133_16206272577  2022-03-23T02:52:37.996Z
#
#                                      query  viewCount taggedFullName21  \
# 0  https://www.instagram.com/sgchildrensoc        NaN              NaN
# 1  https://www.instagram.com/sgchildrensoc        NaN              NaN
# 2  https://www.instagram.com/sgchildrensoc       91.0              NaN
# 3  https://www.instagram.com/sgchildrensoc        NaN              NaN
# 4  https://www.instagram.com/sgchildrensoc        NaN              NaN
#
#   taggedUsername21 taggedFullName22 taggedUsername22 taggedFullName23  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#   taggedUsername23
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
display(commentDF.head())
# Out:
#                                       query              error  \
# 0  https://www.instagram.com/p/CbW1HoSrDt0/  No comments found
# 1  https://www.instagram.com/p/CbHbKk2rDGb/                NaN
# 2  https://www.instagram.com/p/CazGZk4PcV9/  No comments found
# 3  https://www.instagram.com/p/Caoe0jUsfQh/  No comments found
# 4  https://www.instagram.com/p/Cal6BHIPdm7/  No comments found
#
#                   timestamp  \
# 0  2022-03-22T04:16:29.731Z
# 1  2022-03-22T04:16:30.894Z
# 2  2022-03-22T04:16:31.314Z
# 3  2022-03-22T04:16:31.549Z
# 4  2022-03-22T04:16:31.779Z
#
#                                    profilePictureUrl   username  \
# 0                                                NaN        NaN
# 1  https://scontent-vie1-1.cdninstagram.com/v/t51...  jitkaurrr
# 2                                                NaN        NaN
# 3                                                NaN        NaN
# 4                                                NaN        NaN
#
#                             profileUrl comment  likeCount  replyCount  \
# 0                                  NaN     NaN        NaN         NaN
# 1  https://www.instagram.com/jitkaurrr      👏👏        1.0         0.0
# 2                                  NaN     NaN        NaN         NaN
# 3                                  NaN     NaN        NaN         NaN
# 4                                  NaN     NaN        NaN         NaN
#
#                 commentDate     commentId       ownerId
# 0                       NaN           NaN           NaN
# 1  2022-03-18T00:35:55.000Z  1.794178e+16  3.226968e+10
# 2                       NaN           NaN           NaN
# 3                       NaN           NaN           NaN
# 4                       NaN           NaN           NaN

# %% [markdown]
# 1. send all comments to sentimental analysis
# 2. word cloud on caption
#
# 3. timeseries chart-hastag, likes, content(post)
#
# 4. statistics (follower/followering, avg media per post, number of photo, video)
# 5. Users that like each posts (% of them followering)
#
# 6. tagged post

# %% [markdown]
# # Basic Statistics #

# %%
def getFolloweringPercentage(arr1, arr2):
    count = 0
    
    for followering in arr1:
        if (followering in arr2):
            count += 1
    return count/len(arr1)

# %%
def getHashtag(arr):
    
    result = []
    
    for each_sentence in arr:
        # print(each_sentence)
        # if "#" in each_sentence:
        result.extend(re.findall(r"#(\w+)", each_sentence))
    
    return result

# %%
def getHashtagdict(arr, unique):
    result = {}
    for word in unique:
        result[word] = arr.count(word)
    return result

# %%
statsDictionary = {}
statsDictionary["follower"] = followerDF["username"].unique().tolist()
statsDictionary["followerVerified"] = followerDF[followerDF["isVerified"]]["username"].unique().tolist()
statsDictionary["followerPrivate"] = followerDF[followerDF["isPrivate"]]["username"].unique().tolist()

statsDictionary["followering"] = followingDF["username"].unique().tolist()
statsDictionary["followeringVerified"] = followingDF[followingDF["isVerified"]]["username"].unique().tolist()
statsDictionary["followeringPrivate"] = followingDF[followingDF["isPrivate"]]["username"].unique().tolist()

statsDictionary["commentUser"] =  commentDF[commentDF["username"].notna()]["username"].unique().tolist()

statsDictionary["postHashtag"] =  getHashtag(postDF[postDF["description"].notna()]["description"].tolist())

# %%
# Testing
commentDF[commentDF["username"].notna()]["username"].unique().tolist()[:10]
# Out:
# ['jitkaurrr',
#  's_h_e_a_l_y_n_n',
#  'amkfsccommunityservices',
#  'ikin.croffisa',
#  'rac_sg',
#  'stoke_107',
#  'sgpools',
#  'its_saffiyah',
#  'alice86_liz',
#  'chuyaomin']

# %%
print("SCS Statistics")
print(f"Followers count: {len(statsDictionary['follower'])}")
print(f"Verified Followers count: {len(statsDictionary['followerVerified'])}")
print(f"Private Followers count: {len(statsDictionary['followerPrivate'])}")

print("\n----------------------------------------------\n")

print(f"Followings count: {len(statsDictionary['followering'])}")
print(f"Verified Followings count: {len(statsDictionary['followeringVerified'])}")
print(f"Private Followings count: {len(statsDictionary['followeringPrivate'])}")

print(f'Percentage of Followerings in Followers: {getFolloweringPercentage(statsDictionary["followering"], statsDictionary["follower"])}')

print("\n----------------------------------------------\n")

print(f'Total posts: {len(postDF["postUrl"].unique())}')
print(f'Average media per post: {len(postDF)/len(postDF["postUrl"].unique())}')
# postDF["imgUrl"].notna().sum()
print(f'Images count: {len(postDF[postDF["type"] == "Photo"])}')
print(f'Video count: {len(postDF[postDF["type"] == "Video"])}')


print("\n----------------------------------------------\n")
print(f'Total comments: {commentDF["username"].notna().sum()}')
print(f'Average comments/post: {commentDF["username"].notna().sum() / len(postDF["postUrl"].unique())}')
print(f'% commenters/followers: {getFolloweringPercentage(statsDictionary["commentUser"], statsDictionary["follower"])}')
print(f'\nTotal Hashtag (non-unique): {len(statsDictionary["postHashtag"])}')
print(f'Average Hashtag per post: {len(statsDictionary["postHashtag"]) / len(postDF["postUrl"].unique())}')
print(f'Total Hashtag (unique): {len(set(statsDictionary["postHashtag"]))}')
print(f'Reusability rate: {len(statsDictionary["postHashtag"]) / len(set(statsDictionary["postHashtag"]))}')


print("\n----------------------------------------------\n")
print(f'Tagged posts: {len(taggedpostDF)}')
# Out:
# SCS Statistics
# Followers count: 3488
# Verified Followers count: 16
# Private Followers count: 1918
#
# ----------------------------------------------
#
# Followings count: 65
# Verified Followings count: 16
# Private Followings count: 5
# Percentage of Followerings in Followers: 0.6461538461538462
#
# ----------------------------------------------
#
# Total posts: 747
# Average media per post: 1.9732262382864791
# Images count: 1371
# Video count: 103
#
# ----------------------------------------------
#
# Total comments: 237
# Average comments/post: 0.3172690763052209
# % commenters/followers: 0.461038961038961
#
# Total Hashtag (non-unique): 3718
# Average Hashtag per post: 4.977242302543507
# Total Hashtag (unique): 570
# Reusability rate: 6.52280701754386
#
# ----------------------------------------------
#
# Tagged posts: 467

# %%
# Hashtag from posts
sorted_hashtag = sorted(statsDictionary["postHashtag"], key=Counter(statsDictionary["postHashtag"]).get, reverse=True)
unique_hashtag = list(dict.fromkeys(sorted_hashtag))
hashtag_dict = getHashtagdict(statsDictionary["postHashtag"],unique_hashtag)

hashtagDF = pd.DataFrame(hashtag_dict.items(), columns = ["Hashtag", "Count"])
hashtagDF.head(10)
# Out:
#                      Hashtag  Count
# 0                    charity    123
# 1          sgchildrensociety    103
# 2  singaporechildrenssociety     89
# 3                fundraising     79
# 4           livebelowtheline     74
# 5                   children     66
# 6    livebelowthelinewithSCS     66
# 7                 EndPoverty     66
# 8                donatetoday     63
# 9                 CSCturns10     61

# %%
trydate = postDF["pubDate"].tolist()[0]
print(trydate)
df_date = pd.to_datetime(postDF["pubDate"])
# Out:
# 2022-03-22T03:23:22.000Z

# %% [markdown]
# # Create Json object for Lambda Amazon #

# %%
# Comment array
data = commentDF[commentDF["comment"].notna()]["comment"].tolist()
print(data[:5])
# Out:
# ['👏👏', '@cherylongkx @cool_zillavince', 'Congratulations on 70 years! 💪✨', 'Thank you for the memories. It was an honour to have worked as a teacher there. @nsd_be', 'Hi @sgchildrensoc pls check dm thank you']

# %%
import json
with open('data.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

# %%
import json
with open('SCS_Comments.json', 'w') as f:
    json.dump(data, f)

# %% [markdown]
# ## AWS result ##

# %%
with open("./aws/SCS_comments.json.json", 'r') as f:
    jsonData = json.load(f)

print(jsonData[0])
# Out:
# {'Sentiment': 'NEUTRAL', 'SentimentScore': {'Positive': 0.03435271978378296, 'Negative': 0.003817102639004588, 'Neutral': 0.9475383162498474, 'Mixed': 0.014291895553469658}, 'ResponseMetadata': {'RequestId': '6c1e7217-e5fd-4a11-aa6b-65a1381dc0e6', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '6c1e7217-e5fd-4a11-aa6b-65a1381dc0e6', 'content-type': 'application/x-amz-json-1.1', 'content-length': '163', 'date': 'Wed, 23 Mar 2022 04:51:47 GMT'}, 'RetryAttempts': 0}}

# %%
print(len(jsonData))
resultDict = {}
resultDict["comment"] = data
resultDict["sentiment"] = list(map(lambda x : x["Sentiment"] , jsonData))
resultDict["positiveScore"] = list(map(lambda x : x["SentimentScore"]["Positive"] , jsonData))
resultDict["negativeScore"] = list(map(lambda x : x["SentimentScore"]["Negative"] , jsonData))
resultDict["neutralScore"] = list(map(lambda x : x["SentimentScore"]["Neutral"] , jsonData))
resultDict["mixedScore"] = list(map(lambda x : x["SentimentScore"]["Mixed"] , jsonData))

sentimentDF = pd.DataFrame(resultDict)
sentimentDF.head(10)
# Out:
# 237
#                                              comment sentiment  positiveScore  \
# 0                                                 👏👏   NEUTRAL       0.034353
# 1                      @cherylongkx @cool_zillavince   NEUTRAL       0.020442
# 2                    Congratulations on 70 years! 💪✨  POSITIVE       0.998805
# 3  Thank you for the memories. It was an honour t...  POSITIVE       0.995531
# 4           Hi @sgchildrensoc pls check dm thank you  POSITIVE       0.750932
# 5             Promote it on @Mentalhealth_.community   NEUTRAL       0.004531
# 6  Hope you guys enjoyed the game! #RiseandRoar #...  POSITIVE       0.991214
# 7  only took part in a few activities conducted b...  POSITIVE       0.993079
# 8  One of the children in CC1. There since 3yrs o...   NEUTRAL       0.017452
# 9  Can send the recording link to rewatch this ev...   NEUTRAL       0.148147
#
#    negativeScore  neutralScore  mixedScore
# 0       0.003817      0.947538    0.014292
# 1       0.001561      0.976628    0.001369
# 2       0.000073      0.001095    0.000026
# 3       0.000090      0.004326    0.000053
# 4       0.002515      0.240925    0.005629
# 5       0.000248      0.995198    0.000023
# 6       0.000138      0.008571    0.000077
# 7       0.000325      0.002811    0.003785
# 8       0.005333      0.977102    0.000113
# 9       0.032190      0.812657    0.007006

# %%
sentimentDF["sentiment"].value_counts()
# Out:
# POSITIVE    113
# NEUTRAL     111
# NEGATIVE     12
# MIXED         1
# Name: sentiment, dtype: int64

# %% [markdown]
# # Download all photos (Don't run first haha) #

# %%
# Download
statsDictionary["followerDp"] = followerDF["imgUrl"].tolist()
statsDictionary["followingDp"] = followingDF["imgUrl"].tolist()

print(f'Download check: {len(statsDictionary["followerDp"]) == len(statsDictionary["follower"])}')
print(f'Download check: {len(statsDictionary["followingDp"]) == len(statsDictionary["followering"])}')
# Out:
# Download check: (11698, 11698)
# Download check: True

# %%
# Download
for i in range(len(statsDictionary["followerDp"])):
    urllib.request.urlretrieve( statsDictionary["followerDp"][i], './photos/followers/{}.jpg'.format(statsDictionary["follower"][i]))

for i in range(len(statsDictionary["followingDp"])):
    urllib.request.urlretrieve( statsDictionary["followingDp"][i], './photos/followerings/{}.jpg'.format(statsDictionary["followering"][i]))
