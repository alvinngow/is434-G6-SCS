# %% [markdown]
# ### Analysis on image labels

# %%
import os
import json
import itertools
import numpy as np
import pandas as pd
from pprint import pprint
from os.path import exists as file_exists

# Import the wordcloud library
from wordcloud import WordCloud

from ast import literal_eval

import urllib.request

import nltk; nltk.download('stopwords')
from nltk.corpus import stopwords

import spacy

from nltk.tokenize import word_tokenize

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# spacy for lemmatization
import spacy

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Draculabites\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
parent = os.path.dirname(os.getcwd())
parent
# Out:
# 'C:\\Users\\Draculabites\\Desktop\\IS434 SA G2\\Project\\is434-G6-SCS'

# %%
df = pd.read_csv("data/allposts.csv")
df.head()
# Out:
#                                     postUrl  \
# 0  https://www.instagram.com/p/CbzXkYBsSZ0/
# 1  https://www.instagram.com/p/CbhK4IQKwcd/
# 2  https://www.instagram.com/p/CbeksJWrCPZ/
# 3  https://www.instagram.com/p/CbeksJWrCPZ/
# 4  https://www.instagram.com/p/CbeksJWrCPZ/
#
#                                          description  commentCount  likeCount  \
# 0  Happy 1st April! This means that… Our Virtual ...             0         12
# 1  👀 Take a peep into #adayinthelife of a youth w...             1         36
# 2  Singapore Children’s Society held the 1000 Ent...             0         46
# 3  Singapore Children’s Society held the 1000 Ent...             0         46
# 4  Singapore Children’s Society held the 1000 Ent...             0         46
#
#                     pubDate likedByViewer isSidecar   type  \
# 0  2022-04-01T09:00:22.000Z         False     False  Photo
# 1  2022-03-25T07:23:46.000Z         False     False  Video
# 2  2022-03-24T07:10:56.000Z         False      True  Photo
# 3  2022-03-24T07:10:56.000Z         False      True  Photo
# 4  2022-03-24T07:10:56.000Z         False      True  Photo
#
#                                 profileUrl       username  ...  \
# 0  https://www.instagram.com/sgchildrensoc  sgchildrensoc  ...
# 1  https://www.instagram.com/sgchildrensoc  sgchildrensoc  ...
# 2  https://www.instagram.com/sgchildrensoc  sgchildrensoc  ...
# 3  https://www.instagram.com/sgchildrensoc  sgchildrensoc  ...
# 4  https://www.instagram.com/sgchildrensoc  sgchildrensoc  ...
#
#            taggedFullName1     taggedUsername1 taggedFullName2  \
# 0                      NaN                 NaN             NaN
# 1                  GIG@JYC          jyc_at_scs             NaN
# 2  PARKROYAL on Beach Road  parkroyalbeachroad   Teo Chee Hean
# 3  PARKROYAL on Beach Road  parkroyalbeachroad   Teo Chee Hean
# 4  PARKROYAL on Beach Road  parkroyalbeachroad   Teo Chee Hean
#
#   taggedUsername2 taggedFullName3 taggedUsername3  taggedFullName4  \
# 0             NaN             NaN             NaN              NaN
# 1             NaN             NaN             NaN              NaN
# 2     teocheehean             NaN             NaN              NaN
# 3     teocheehean             NaN             NaN              NaN
# 4     teocheehean             NaN             NaN              NaN
#
#   taggedUsername4 location locationId
# 0             NaN      NaN        NaN
# 1             NaN      NaN        NaN
# 2             NaN      NaN        NaN
# 3             NaN      NaN        NaN
# 4             NaN      NaN        NaN
#
# [5 rows x 27 columns]

# %%
urls = list(df.imgUrl)

# For parsing into aws
with open('data/urls.json', 'w') as f:
    json.dump(urls, f)

# %% [markdown]
# **Move over to AWS Rekognition to get**
# 1. **image labels**
# 2. **text detection**
#
# & then continue from this script

# %%
# text_all = []
# with open(f"data/images_text/261.json") as f:
#     lists = json.load(f)
#     for li in lists:
#         temp = []
#         for arr in li:
#             temp.append(arr["DetectedText"])
#         text_all.append(temp)
                      
# len(text_all)

# %%
len(df)
# Out:
# 1481

# %%
text_all = []
for i in [261, 1045, 1481]:
    # check if file exists, i.e. no text detected
    # break out of the loop and continue from the next image
    if not file_exists(f"data/images_text/{i}.json"):
        df.drop(i-1, inplace = True)
        continue
    fp = f"data/images_text/{i}.json"
    with open(fp) as f:
        lists = json.load(f)
        for li in lists:
            temp = []
            for arr in li:
                temp.append(arr["DetectedText"])
            text_all.append(temp)
            
text_all
# Out:
# [["Children 'sv",
#   'SOCIET',
#   'Caring for the Futuro',
#   '7a and',
#   'smiles hope',
#   'Since 1952',
#   'This Virtual Flag Day, drop an e-token of love and pass it on.',
#   'Fill a bucket full of hope for those in need today!',
#   'Virtual Flag',
#   'Day 2022',
#   'DONATE',
#   'HOPE',
#   'Children',
#   "'sv",
#   'SOCIET',
#   'Caring',
#   'for the',
#   'Futuro',
#   '7a',
#   'and',
#   'smiles',
#   'hope',
#   'Since',
#   '1952',
#   'This',
#   'Virtual',
#   'Flag',
#   'Day,',
#   'drop',
#   'an',
#   'e-token',
#   'of',
#   'love',
#   'and',
#   'pass',
#   'it',
#   'on.',
#   'Fill',
#   'a',
#   'bucket',
#   'full',
#   'of',
#   'hope',
#   'for',
#   'those',
#   'in',
#   'need',
#   'today!',
#   'Virtual',
#   'Flag',
#   'Day',
#   '2022',
#   'DONATE',
#   'HOPE'],
#  ['A Day in the',
#   'Life of a Youth',
#   'Worker From',
#   'jyc @',
#   "Children's",
#   'Society',
#   'A',
#   'Day',
#   'in',
#   'the',
#   'Life',
#   'of',
#   'a',
#   'Youth',
#   'Worker',
#   'From',
#   'jyc',
#   '@',
#   "Children's",
#   'Society'],
#  ['-',
#   '70ml and',
#   'ENTERPRISES',
#   '1000 ENTERPRISES FOR CHILDREN-IN-NEED',
#   '- hope',
#   'FOR',
#   '1000',
#   'CHILDREN-IN-NEED',
#   'LANTHROPISTS',
#   'New 1902',
#   'AND 1000 PHILANTHROPISTS',
#   'APPRECIATION',
#   'EV',
#   'IT 2022',
#   'MARCH 2022',
#   'INOUR',
#   'HEAN',
#   'ISTER FOR',
#   'CURITY',
#   '-',
#   '70ml',
#   'and',
#   'ENTERPRISES',
#   '1000',
#   'ENTERPRISES',
#   'FOR',
#   'CHILDREN-IN-NEED',
#   '-',
#   'hope',
#   'FOR',
#   '1000',
#   'CHILDREN-IN-NEED',
#   'LANTHROPISTS',
#   'New',
#   '1902',
#   'AND',
#   '1000',
#   'PHILANTHROPISTS',
#   'APPRECIATION',
#   'EV',
#   'IT',
#   '2022',
#   'MARCH',
#   '2022',
#   'INOUR',
#   'HEAN',
#   'ISTER',
#   'FOR',
#   'CURITY'],
#  ['ENTE',
#   '1000 ENTERPRISES FOR CHILDREN-IN-NEED',
#   'CHILD',
#   'AND 1000 PHILANTHROPISTS',
#   'APPRECIATION',
#   'EVENT 2022',
#   '23 MARCH 2022',
#   'GUEST-OF-HONOUR',
#   'MR TEO CHEE НЕ',
#   'D COORDINATING MIN',
#   'RITY',
#   'ENTE',
#   '1000',
#   'ENTERPRISES',
#   'FOR',
#   'CHILDREN-IN-NEED',
#   'CHILD',
#   'AND',
#   '1000',
#   'PHILANTHROPISTS',
#   'APPRECIATION',
#   'EVENT',
#   '2022',
#   '23',
#   'MARCH',
#   '2022',
#   'GUEST-OF-HONOUR',
#   'MR',
#   'TEO',
#   'CHEE',
#   'НЕ',
#   'D',
#   'COORDINATING',
#   'MIN',
#   'RITY'],
#  [],
#  ['1000 ENTERPRISES FOR CHILDREN-IN-NEED',
#   'ENTERPRISES',
#   'FOR',
#   'AND 1000 PHILANTHROPISTS',
#   'CHILDREN IN NEED',
#   '1000',
#   'APPRECIATION',
#   'EV',
#   'T 2022',
#   'ARCH 2022',
#   'NOUR',
#   'HEAN',
#   'STER FOR NATIONAL SECURITY',
#   'SENIOR',
#   '1000',
#   'ENTERPRISES',
#   'FOR',
#   'CHILDREN-IN-NEED',
#   'ENTERPRISES',
#   'FOR',
#   'AND',
#   '1000',
#   'PHILANTHROPISTS',
#   'CHILDREN',
#   'IN NEED',
#   '1000',
#   'APPRECIATION',
#   'EV',
#   'T',
#   '2022',
#   'ARCH',
#   '2022',
#   'NOUR',
#   'HEAN',
#   'STER',
#   'FOR',
#   'NATIONAL',
#   'SECURITY',
#   'SENIOR'],
#  ['years',
#   'Children',
#   'ozime hope',
#   'SOCIET',
#   'Canno for the Class',
#   'To br',
#   'orga',
#   'the W',
#   'years',
#   'Children',
#   'ozime',
#   'hope',
#   'SOCIET',
#   'Canno',
#   'for',
#   'the',
#   'Class',
#   'To',
#   'br',
#   'orga',
#   'the',
#   'W'],
#  ['MAKE',
#   'SINGA',
#   'EVERY',
#   'لله',
#   'TTR',
#   'TYR',
#   'CA4458 feelfree',
#   'SAMELOT',
#   'CAMELOT',
#   'MAKE',
#   'SINGA',
#   'EVERY',
#   'لله',
#   'TTR',
#   'TYR',
#   'CA4458',
#   'feelfree',
#   'SAMELOT',
#   'CAMELOT'],
#  ['y-Free',
#   '-',
#   'Onion',
#   '-',
#   'WA',
#   '-',
#   '- -',
#   'Need someone to talk to?',
#   'Speak to Tinkle Friend',
#   '-',
#   '-',
#   'The',
#   '-',
#   '-',
#   'tus',
#   'y-Free',
#   '-',
#   'Onion',
#   '-',
#   'WA',
#   '-',
#   '-',
#   '-',
#   'Need',
#   'someone',
#   'to',
#   'talk',
#   'to?',
#   'Speak',
#   'to',
#   'Tinkle',
#   'Friend',
#   '-',
#   '-',
#   'The',
#   '-',
#   '-',
#   'tus'],
#  ['Bee Joo (the one squatting down), our staff and volunteer engaging in role play during training',
#   'session for the story of "The Hen that Laid the Golden Eggs" in 2000. This was under Choo Choo',
#   'Train, a programme to inculcate positive values in young children through story telling and role',
#   'The',
#   '-',
#   'SAN',
#   'play.',
#   'Tutual',
#   'SKOP',
#   'HEART AGH',
#   'your',
#   'Ideas',
#   'Bee',
#   'Joo',
#   '(the',
#   'one',
#   'squatting',
#   'down),',
#   'our',
#   'staff',
#   'and',
#   'volunteer',
#   'engaging',
#   'in',
#   'role',
#   'play',
#   'during',
#   'training',
#   'session',
#   'for',
#   'the',
#   'story',
#   'of',
#   '"The',
#   'Hen',
#   'that',
#   'Laid',
#   'the',
#   'Golden',
#   'Eggs"',
#   'in',
#   '2000.',
#   'This',
#   'was',
#   'under',
#   'Choo',
#   'Choo',
#   'Train,',
#   'a',
#   'programme',
#   'to',
#   'inculcate',
#   'positive',
#   'values',
#   'in',
#   'young',
#   'children',
#   'through',
#   'story',
#   'telling',
#   'and',
#   'role',
#   'The',
#   '-',
#   'SAN',
#   'play.',
#   'Tutual',
#   'SKOP',
#   'HEART',
#   'AGH',
#   'your',
#   'Ideas'],
#  ["Bee Joo with Ms Gaja, one of Children's Society pioneer social workers in",
#   '1999. Ms Gaja served the Society for more than 40 years before she',
#   'retired early 2000.',
#   'Bee',
#   'Joo',
#   'with',
#   'Ms',
#   'Gaja,',
#   'one',
#   'of',
#   "Children's",
#   'Society',
#   'pioneer',
#   'social',
#   'workers',
#   'in',
#   '1999.',
#   'Ms',
#   'Gaja',
#   'served',
#   'the',
#   'Society',
#   'for',
#   'more',
#   'than',
#   '40',
#   'years',
#   'before',
#   'she',
#   'retired',
#   'early',
#   '2000.'],
#  ['CABIN',
#   'Bee Joo conducting a training programme',
#   'for CABIN Club members in 2004,',
#   'CABIN',
#   'Bee',
#   'Joo',
#   'conducting',
#   'a',
#   'training',
#   'programme',
#   'for',
#   'CABIN',
#   'Club',
#   'members',
#   'in',
#   '2004,'],
#  ["Thank you Singapore Children's Society for giving me the opportunity to",
#   'serve the many children and their families in need for the past 24 years. I',
#   'hope the Society will continue to grow, stay relevant and do good work in',
#   'the many more years to come! Thank you for making a difference! - Bee',
#   'Joo in 2022',
#   'Thank',
#   'you',
#   'Singapore',
#   "Children's",
#   'Society',
#   'for',
#   'giving',
#   'me',
#   'the',
#   'opportunity',
#   'to',
#   'serve',
#   'the',
#   'many',
#   'children',
#   'and',
#   'their',
#   'families',
#   'in',
#   'need',
#   'for',
#   'the',
#   'past',
#   '24',
#   'years.',
#   'I',
#   'hope',
#   'the',
#   'Society',
#   'will',
#   'continue',
#   'to',
#   'grow,',
#   'stay',
#   'relevant',
#   'and',
#   'do',
#   'good',
#   'work',
#   'in',
#   'the',
#   'many',
#   'more',
#   'years',
#   'to',
#   'come!',
#   'Thank',
#   'you',
#   'for',
#   'making',
#   'a',
#   'difference! - Bee',
#   'Joo',
#   'in',
#   '2022'],
#  ["Children's",
#   'SOCIETY',
#   'Caring for the Future',
#   '$5',
#   'Donation',
#   'YOUR DONATION,',
#   'big or small will impact the lives of',
#   'our children, youth and families in need',
#   "Children's",
#   'SOCIETY',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   '$5',
#   'Donation',
#   'YOUR',
#   'DONATION,',
#   'big',
#   'or',
#   'small',
#   'will',
#   'impact',
#   'the',
#   'lives',
#   'of',
#   'our',
#   'children,',
#   'youth',
#   'and',
#   'families',
#   'in',
#   'need'],
#  ["Children's",
#   'SOCIETY',
#   'Caring for the Future',
#   '$10',
#   'Donation',
#   'YOUR DONATION,',
#   'big or small will impact the lives of',
#   'our children, youth and families in need',
#   "Children's",
#   'SOCIETY',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   '$10',
#   'Donation',
#   'YOUR',
#   'DONATION,',
#   'big',
#   'or',
#   'small',
#   'will',
#   'impact',
#   'the',
#   'lives',
#   'of',
#   'our',
#   'children,',
#   'youth',
#   'and',
#   'families',
#   'in',
#   'need'],
#  ["Children's",
#   'SOCIETY',
#   'Caring for the Future',
#   '$20',
#   'Donation',
#   'YOUR DONATION,',
#   'big or small will impact the lives of',
#   'our children, youth and families in need',
#   "Children's",
#   'SOCIETY',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   '$20',
#   'Donation',
#   'YOUR',
#   'DONATION,',
#   'big',
#   'or',
#   'small',
#   'will',
#   'impact',
#   'the',
#   'lives',
#   'of',
#   'our',
#   'children,',
#   'youth',
#   'and',
#   'families',
#   'in',
#   'need'],
#  ["Children's",
#   'SOCIETY',
#   '70 smiles',
#   'and hope',
#   'Caring for the Future',
#   'Since 1952',
#   'How Do Low-Income',
#   'Families Experience',
#   'Food Insecurity?',
#   "Children's",
#   'SOCIETY',
#   '70',
#   'smiles',
#   'and',
#   'hope',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   'Since',
#   '1952',
#   'How',
#   'Do',
#   'Low-Income',
#   'Families',
#   'Experience',
#   'Food',
#   'Insecurity?'],
#  ['Children S',
#   'SOCIETY',
#   'Caring for the Future',
#   '70 hope',
#   'and smiles',
#   'Since 1952',
#   '?',
#   'The Decision-Making',
#   'Experiences of',
#   'Bystander Witnesses to',
#   'Suspected Child Abuse',
#   'Children',
#   'S',
#   'SOCIETY',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   '70',
#   'hope',
#   'and',
#   'smiles',
#   'Since',
#   '1952',
#   '?',
#   'The',
#   'Decision-Making',
#   'Experiences',
#   'of',
#   'Bystander',
#   'Witnesses',
#   'to',
#   'Suspected',
#   'Child',
#   'Abuse'],
#  ["Children's",
#   'SOCIETY',
#   'smiles',
#   'Caring for the Future',
#   '70 and hope',
#   'Since 1952',
#   'Parenting as a',
#   'Balancing Act:',
#   'Challenges Relating',
#   'to Involvement in',
#   'Time',
#   'Work',
#   "Children's Education",
#   'Parentine',
#   "Children's",
#   'SOCIETY',
#   'smiles',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   '70',
#   'and',
#   'hope',
#   'Since',
#   '1952',
#   'Parenting',
#   'as',
#   'a',
#   'Balancing',
#   'Act:',
#   'Challenges',
#   'Relating',
#   'to',
#   'Involvement',
#   'in',
#   'Time',
#   'Work',
#   "Children's",
#   'Education',
#   'Parentine'],
#  ["Children's",
#   'SOCIETY',
#   'Tips from the Expert',
#   'Caring for the Future',
#   'My son just confided that that he is a bully in',
#   'school. Не tells me although it makes him',
#   'feel good, he is not proud of it and wants to',
#   'change. How do I help him?',
#   'Start by affirming your child for wanting to change his',
#   'bullying behaviour and pledge your support for him.',
#   "Listen to your son's struggles and teach him about",
#   'respectful and responsible communications. Practise',
#   'these conversations with him.',
#   'Teach your child about perspective taking and facilitate',
#   'apologies. Work towards restoring safety and peer',
#   'relationships. Monitor your',
#   "Children's",
#   'SOCIETY',
#   'Tips',
#   'from',
#   'the',
#   'Expert',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   'My',
#   'son',
#   'just',
#   'confided',
#   'that',
#   'that',
#   'he',
#   'is',
#   'a',
#   'bully',
#   'in',
#   'school.',
#   'Не',
#   'tells',
#   'me',
#   'although',
#   'it',
#   'makes',
#   'him',
#   'feel',
#   'good,',
#   'he',
#   'is',
#   'not',
#   'proud',
#   'of',
#   'it',
#   'and',
#   'wants',
#   'to',
#   'change.',
#   'How',
#   'do',
#   'I',
#   'help',
#   'him?',
#   'Start',
#   'by',
#   'affirming',
#   'your',
#   'child',
#   'for',
#   'wanting',
#   'to',
#   'change',
#   'his',
#   'bullying',
#   'behaviour',
#   'and',
#   'pledge',
#   'your',
#   'support',
#   'for',
#   'him.',
#   'Listen',
#   'to',
#   'your',
#   "son's",
#   'struggles',
#   'and',
#   'teach',
#   'him',
#   'about',
#   'respectful',
#   'and',
#   'responsible',
#   'communications.',
#   'Practise',
#   'these',
#   'conversations',
#   'with',
#   'him.',
#   'Teach',
#   'your',
#   'child',
#   'about',
#   'perspective',
#   'taking',
#   'and',
#   'facilitate',
#   'apologies.',
#   'Work',
#   'towards',
#   'restoring',
#   'safety',
#   'and',
#   'peer',
#   'relationships.',
#   'Monitor',
#   'your'],
#  ['X',
#   'f',
#   'LIVE',
#   '66',
#   '958',
#   'b',
#   'pas',
#   'X',
#   'f',
#   'LIVE',
#   '66',
#   '958',
#   'b',
#   'pas'],
#  [],
#  ['A LiTTLe KiNDNeSS.',
#   'LOTS OF JOY!',
#   'Children',
#   'of and bringing smiles',
#   'hope',
#   'SOCIET',
#   'Caring for the Future',
#   'LUNAR NEW YEAR 2022',
#   'Since 19',
#   'This Lunar New Year,',
#   'donate to our project',
#   '& fill the hearts of our beneficiaries',
#   'with extra love & joy.',
#   'Foster the value of giving',
#   '& get the little ones involved too!',
#   'Continue supporting us in making',
#   'a positive impact to our children,',
#   'youth, and families in need!',
#   'A',
#   'LiTTLe',
#   'KiNDNeSS.',
#   'LOTS',
#   'OF',
#   'JOY!',
#   'Children',
#   'of',
#   'and',
#   'bringing',
#   'smiles',
#   'hope',
#   'SOCIET',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   'LUNAR',
#   'NEW',
#   'YEAR',
#   '2022',
#   'Since',
#   '19',
#   'This',
#   'Lunar',
#   'New',
#   'Year,',
#   'donate',
#   'to',
#   'our',
#   'project',
#   '&',
#   'fill',
#   'the',
#   'hearts',
#   'of',
#   'our',
#   'beneficiaries',
#   'with',
#   'extra',
#   'love',
#   '&',
#   'joy.',
#   'Foster',
#   'the',
#   'value',
#   'of',
#   'giving',
#   '&',
#   'get',
#   'the',
#   'little',
#   'ones',
#   'involved',
#   'too!',
#   'Continue',
#   'supporting',
#   'us',
#   'in',
#   'making',
#   'a',
#   'positive',
#   'impact',
#   'to',
#   'our',
#   'children,',
#   'youth,',
#   'and',
#   'families',
#   'in',
#   'need!'],
#  ['Children SV',
#   'and bringing smiles',
#   'of',
#   'hope',
#   'SOCIET',
#   'Caring for the Future',
#   'Since 1952',
#   'Children',
#   'SV',
#   'and',
#   'bringing',
#   'smiles',
#   'of',
#   'hope',
#   'SOCIET',
#   'Caring',
#   'for the',
#   'Future',
#   'Since',
#   '1952'],
#  ['Children',
#   'SOCIET',
#   'Caring for the Future',
#   '70 and smiles',
#   'bringing hope',
#   'Since 1952',
#   'Children',
#   'SOCIET',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   '70',
#   'and',
#   'smiles',
#   'bringing',
#   'hope',
#   'Since',
#   '1952'],
#  ["Children's",
#   'and bringing smiles',
#   'hope',
#   'SOCIETY',
#   'Caring for the Future',
#   'Since 1952',
#   "Children's",
#   'and',
#   'bringing',
#   'smiles',
#   'hope',
#   'SOCIETY',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   'Since',
#   '1952'],
#  ["Children's",
#   '70 and smiles',
#   'bringing hope',
#   'KEY BODY SAFETY',
#   'Caring for the Future',
#   'Since 1952',
#   'MESSAGES',
#   'TO TEACH CHILDREN',
#   "Children's",
#   '70',
#   'and',
#   'smiles',
#   'bringing',
#   'hope',
#   'KEY',
#   'BODY',
#   'SAFETY',
#   'Caring',
#   'for the',
#   'Future',
#   'Since',
#   '1952',
#   'MESSAGES',
#   'TO',
#   'TEACH',
#   'CHILDREN'],
#  ['Teach your child the proper',
#   '70 bringing hope',
#   'and smiles',
#   'Caring for the Future',
#   'terms of their private body',
#   'Since 1952',
#   'parts. No nicknames please!',
#   'My private body',
#   'parts are covered',
#   'by my underwear.',
#   'breasts',
#   'groin',
#   'groin',
#   'penis',
#   'backside',
#   'vulva',
#   'testicles',
#   'This will help them develop a healthy',
#   'respect for their own bodies.',
#   'Teach',
#   'your',
#   'child',
#   'the',
#   'proper',
#   '70',
#   'bringing',
#   'hope',
#   'and',
#   'smiles',
#   'Caring',
#   'for the',
#   'Future',
#   'terms',
#   'of',
#   'their',
#   'private',
#   'body',
#   'Since',
#   '1952',
#   'parts.',
#   'No',
#   'nicknames',
#   'please!',
#   'My',
#   'private',
#   'body',
#   'parts',
#   'are',
#   'covered',
#   'by',
#   'my',
#   'underwear.',
#   'breasts',
#   'groin',
#   'groin',
#   'penis',
#   'backside',
#   'vulva',
#   'testicles',
#   'This',
#   'will',
#   'help',
#   'them',
#   'develop',
#   'a',
#   'healthy',
#   'respect',
#   'for',
#   'their',
#   'own',
#   'bodies.'],
#  ['Tell your child that no one should',
#   '7a smiles',
#   'and bringing hope',
#   'Caring for the Future',
#   'see or touch their private body',
#   'Since 1952',
#   'parts and vice versa.',
#   'Now you are still young,',
#   "that's why Daddy needs",
#   'to help you keep your',
#   'body clean.',
#   'Explain that parents and caregivers',
#   'can see and touch these parts only',
#   'when there is a good reason.',
#   'Tell',
#   'your',
#   'child',
#   'that',
#   'no',
#   'one',
#   'should',
#   '7a',
#   'smiles',
#   'and',
#   'bringing',
#   'hope',
#   'Caring',
#   'for the',
#   'Future',
#   'see',
#   'or',
#   'touch',
#   'their',
#   'private',
#   'body',
#   'Since',
#   '1952',
#   'parts',
#   'and',
#   'vice',
#   'versa.',
#   'Now',
#   'you',
#   'are',
#   'still',
#   'young,',
#   "that's",
#   'why',
#   'Daddy',
#   'needs',
#   'to',
#   'help',
#   'you',
#   'keep',
#   'your',
#   'body',
#   'clean.',
#   'Explain',
#   'that',
#   'parents',
#   'and',
#   'caregivers',
#   'can',
#   'see',
#   'and',
#   'touch',
#   'these',
#   'parts',
#   'only',
#   'when',
#   'there',
#   'is',
#   'a',
#   'good',
#   'reason.'],
#  ['Emphasise that their body',
#   'and smiles bringing hope',
#   'Caring for the Future',
#   '70',
#   'Since 1952',
#   'belongs to them.',
#   'Give Aunt Sally',
#   'a kiss?',
#   'No!',
#   'They have the right to say "no" to',
#   'any unwanted touches,',
#   'including hugs and kisses.',
#   'Emphasise',
#   'that',
#   'their',
#   'body',
#   'and smiles',
#   'bringing',
#   'hope',
#   'Caring',
#   'for the Future',
#   '70',
#   'Since',
#   '1952',
#   'belongs',
#   'to',
#   'them.',
#   'Give',
#   'Aunt',
#   'Sally',
#   'a',
#   'kiss?',
#   'No!',
#   'They',
#   'have',
#   'the',
#   'right',
#   'to',
#   'say',
#   '"no"',
#   'to',
#   'any',
#   'unwanted',
#   'touches,',
#   'including',
#   'hugs',
#   'and',
#   'kisses.'],
#  ['Caring for the Future',
#   '70 and smiles',
#   'Practice the N.O.T Rules',
#   "Children's",
#   'hope',
#   'SOCIET',
#   'Since 1952',
#   'with your child.',
#   'NO!',
#   'SAY No',
#   'TELL A',
#   'TRUSTED ADULT',
#   'WALK OUT',
#   'Caring',
#   'for the',
#   'Future',
#   '70',
#   'and',
#   'smiles',
#   'Practice',
#   'the',
#   'N.O.T',
#   'Rules',
#   "Children's",
#   'hope',
#   'SOCIET',
#   'Since',
#   '1952',
#   'with',
#   'your',
#   'child.',
#   'NO!',
#   'SAY',
#   'No',
#   'TELL',
#   'A',
#   'TRUSTED',
#   'ADULT',
#   'WALK',
#   'OUT'],
#  ["Children 's",
#   'SOCIET',
#   'Caring for the Future',
#   '70 and bringing smiles hope',
#   'Help your child identify a few',
#   'Since 1952',
#   'trusted adults they can turn to.',
#   'Their trusted adults can include',
#   'people within and outside the family.',
#   '(e.g. teachers, school counsellors)',
#   'Children',
#   "'s",
#   'SOCIET',
#   'Caring',
#   'for the',
#   'Future',
#   '70',
#   'and',
#   'bringing',
#   'smiles',
#   'hope',
#   'Help',
#   'your',
#   'child',
#   'identify',
#   'a',
#   'few',
#   'Since',
#   '1952',
#   'trusted',
#   'adults',
#   'they',
#   'can',
#   'turn',
#   'to.',
#   'Their',
#   'trusted',
#   'adults',
#   'can',
#   'include',
#   'people',
#   'within',
#   'and',
#   'outside',
#   'the',
#   'family.',
#   '(e.g.',
#   'teachers,',
#   'school',
#   'counsellors)'],
#  ['Remind your child that even',
#   'and smiles bringing hope',
#   'Caring find the Fature',
#   '70',
#   'Since 1952',
#   'familiar adults should not',
#   'behave inappropriately',
#   'towards them.',
#   'No!',
#   'What are you',
#   'doing, Uncle?',
#   'Remind',
#   'your',
#   'child',
#   'that',
#   'even',
#   'and smiles',
#   'bringing',
#   'hope',
#   'Caring',
#   'find the Fature',
#   '70',
#   'Since',
#   '1952',
#   'familiar',
#   'adults',
#   'should',
#   'not',
#   'behave',
#   'inappropriately',
#   'towards',
#   'them.',
#   'No!',
#   'What',
#   'are',
#   'you',
#   'doing,',
#   'Uncle?'],
#  ['Caring fine the Future',
#   '70 and smiles bringing hope',
#   'Discuss with your child the',
#   "CHETET'S",
#   'Since 1952',
#   'difference between good',
#   'and bad secrets.',
#   "Shh, don't tell",
#   "anyone and I'll",
#   "Shh, don't tell",
#   'give you this toy.',
#   'Mummy about',
#   'her surprise',
#   'birthday party.',
#   "HAPPY B'DAY",
#   'mo MMY',
#   'Encourage your child to tell you if anyone',
#   'asks them to keep a secret.',
#   'Caring',
#   'fine the Future',
#   '70',
#   'and smiles',
#   'bringing',
#   'hope',
#   'Discuss',
#   'with',
#   'your',
#   'child',
#   'the',
#   "CHETET'S",
#   'Since',
#   '1952',
#   'difference',
#   'between',
#   'good',
#   'and',
#   'bad',
#   'secrets.',
#   'Shh,',
#   "don't",
#   'tell',
#   'anyone',
#   'and',
#   "I'll",
#   'Shh,',
#   "don't",
#   'tell',
#   'give',
#   'you',
#   'this',
#   'toy.',
#   'Mummy',
#   'about',
#   'her',
#   'surprise',
#   'birthday',
#   'party.',
#   'HAPPY',
#   "B'DAY",
#   'mo',
#   'MMY',
#   'Encourage',
#   'your',
#   'child',
#   'to',
#   'tell',
#   'you',
#   'if',
#   'anyone',
#   'asks',
#   'them',
#   'to',
#   'keep',
#   'a',
#   'secret.'],
#  ['70 smiles',
#   'Listen and believe your child if',
#   'and bringing hope',
#   'Caring for the Future',
#   'Since 1952',
#   'they disclose a sexual abuse',
#   'incident.',
#   "Don't worry.",
#   "I'll be here for",
#   'you.',
#   'Assure your child that you and',
#   'other trusted adults will be able',
#   'to support and help them.',
#   '70',
#   'smiles',
#   'Listen',
#   'and',
#   'believe',
#   'your',
#   'child',
#   'if',
#   'and',
#   'bringing',
#   'hope',
#   'Caring',
#   'for the Future',
#   'Since',
#   '1952',
#   'they',
#   'disclose',
#   'a',
#   'sexual',
#   'abuse',
#   'incident.',
#   "Don't",
#   'worry.',
#   "I'll",
#   'be',
#   'here',
#   'for',
#   'you.',
#   'Assure',
#   'your',
#   'child',
#   'that',
#   'you',
#   'and',
#   'other',
#   'trusted',
#   'adults',
#   'will',
#   'be',
#   'able',
#   'to',
#   'support',
#   'and',
#   'help',
#   'them.'],
#  ['70 and smiles',
#   'If you suspect that a child has',
#   'bringing hope',
#   'Caring for the',
#   'been sexually abused, call',
#   'Since 1952',
#   'these helplines.',
#   'National Anti-Violence Helpline (NAVH)',
#   'Tel: 1800 777 0000',
#   'Police',
#   'Tel: 999',
#   'Child Protection Specialist Centres (CPSC)',
#   'HEART @ Fei Yue',
#   'Tel: 6819 9170',
#   'Big Love Child Protection Specialist Centre',
#   'Tel: 6445 0400',
#   'PAVE Integrated Services for Individual and',
#   'Family Protection Specialist Centre',
#   'Tel: 6555 0390',
#   'AWARE Sexual Assault Care Centre',
#   'Tel: 6779 0282',
#   '70',
#   'and',
#   'smiles',
#   'If',
#   'you',
#   'suspect',
#   'that',
#   'a',
#   'child',
#   'has',
#   'bringing',
#   'hope',
#   'Caring',
#   'for the',
#   'been',
#   'sexually',
#   'abused,',
#   'call',
#   'Since',
#   '1952',
#   'these',
#   'helplines.',
#   'National',
#   'Anti-Violence',
#   'Helpline',
#   '(NAVH)',
#   'Tel:',
#   '1800',
#   '777',
#   '0000',
#   'Police',
#   'Tel:',
#   '999',
#   'Child',
#   'Protection',
#   'Specialist',
#   'Centres',
#   '(CPSC)',
#   'HEART',
#   '@',
#   'Fei',
#   'Yue',
#   'Tel:',
#   '6819',
#   '9170',
#   'Big',
#   'Love',
#   'Child',
#   'Protection',
#   'Specialist',
#   'Centre',
#   'Tel:',
#   '6445',
#   '0400',
#   'PAVE',
#   'Integrated',
#   'Services',
#   'for',
#   'Individual',
#   'and',
#   'Family',
#   'Protection',
#   'Specialist',
#   'Centre',
#   'Tel:',
#   '6555',
#   '0390',
#   'AWARE',
#   'Sexual',
#   'Assault',
#   'Care',
#   'Centre',
#   'Tel:',
#   '6779',
#   '0282'],
#  ['UR',
#   'THEME',
#   "Children's Allergy",
#   '2018',
#   'Helpers',
#   '-',
#   '1',
#   'Evacuation Plan',
#   'Photo taken during pre-COVID19 days',
#   'UR',
#   'THEME',
#   "Children's",
#   'Allergy',
#   '2018',
#   'Helpers',
#   '-',
#   '1',
#   'Evacuation',
#   'Plan',
#   'Photo',
#   'taken',
#   'during',
#   'pre-COVID19',
#   'days'],
#  ["Children's",
#   'SOCIETY',
#   'Tips from the Experts',
#   'Caring for the Future',
#   'My friend posted her latest selfie on',
#   'Instagram and has been getting a lot of',
#   "unkind comments and she doesn't know",
#   'what to do next. What can I do to help her?',
#   'You can advise her to delete those comments,',
#   'activate the hide comment feature or to',
#   'change her privacy setting to private.',
#   'Encourage your friend to think through what',
#   'she wants to post next on Instagram if she',
#   'wants to avoid a similar experience.',
#   'Taufiq Salehoodin',
#   'Social Programme Assistant Manager',
#   "Student Service @ Children's Society",
#   "Children's",
#   'SOCIETY',
#   'Tips',
#   'from',
#   'the',
#   'Experts',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   'My',
#   'friend',
#   'posted',
#   'her',
#   'latest',
#   'selfie',
#   'on',
#   'Instagram',
#   'and',
#   'has',
#   'been',
#   'getting',
#   'a',
#   'lot',
#   'of',
#   'unkind',
#   'comments',
#   'and',
#   'she',
#   "doesn't",
#   'know',
#   'what',
#   'to',
#   'do',
#   'next.',
#   'What',
#   'can',
#   'I',
#   'do',
#   'to',
#   'help',
#   'her?',
#   'You',
#   'can',
#   'advise',
#   'her',
#   'to',
#   'delete',
#   'those',
#   'comments,',
#   'activate',
#   'the',
#   'hide',
#   'comment',
#   'feature',
#   'or',
#   'to',
#   'change',
#   'her',
#   'privacy',
#   'setting',
#   'to',
#   'private.',
#   'Encourage',
#   'your',
#   'friend',
#   'to',
#   'think',
#   'through',
#   'what',
#   'she',
#   'wants',
#   'to',
#   'post',
#   'next',
#   'on',
#   'Instagram',
#   'if',
#   'she',
#   'wants',
#   'to',
#   'avoid',
#   'a',
#   'similar',
#   'experience.',
#   'Taufiq',
#   'Salehoodin',
#   'Social',
#   'Programme',
#   'Assistant',
#   'Manager',
#   'Student',
#   'Service',
#   '@',
#   "Children's",
#   'Society'],
#  ["Children's",
#   'S OCIETY',
#   'Caring for the Future',
#   '70th and',
#   'smiles hope',
#   'Since 1952',
#   'Is there someone across the globe',
#   'you wish you could spend the',
#   'Lunar New Year with in person?',
#   'Send them this card to',
#   'tell them you miss them!',
#   "Children's",
#   'S',
#   'OCIETY',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   '70th',
#   'and',
#   'smiles',
#   'hope',
#   'Since',
#   '1952',
#   'Is',
#   'there',
#   'someone',
#   'across',
#   'the',
#   'globe',
#   'you',
#   'wish',
#   'you',
#   'could',
#   'spend',
#   'the',
#   'Lunar',
#   'New',
#   'Year',
#   'with',
#   'in',
#   'person?',
#   'Send',
#   'them',
#   'this',
#   'card',
#   'to',
#   'tell',
#   'them',
#   'you',
#   'miss',
#   'them!'],
#  ["Children's",
#   'SOCIETY',
#   'smiles',
#   'Caring for the Future',
#   '70 and = hope',
#   'Since 1952',
#   'Spread a little kindness this Lunar New Year',
#   '& donate to our project today!',
#   'A LiTTLe KiNDNeSS,',
#   'LOTS OF JOY!',
#   'LUNAR NEW YEAR 2 2022',
#   "Children's",
#   'SOCIETY',
#   'smiles',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   '70',
#   'and',
#   '=',
#   'hope',
#   'Since',
#   '1952',
#   'Spread',
#   'a',
#   'little',
#   'kindness',
#   'this',
#   'Lunar',
#   'New',
#   'Year',
#   '&',
#   'donate',
#   'to',
#   'our',
#   'project',
#   'today!',
#   'A',
#   'LiTTLe',
#   'KiNDNeSS,',
#   'LOTS',
#   'OF',
#   'JOY!',
#   'LUNAR',
#   'NEW YEAR 2',
#   '2022'],
#  ['OUR DIGITAL',
#   'SOCIET',
#   'Podcast',
#   'Caring for the Future',
#   '70th',
#   'and smiles hope',
#   'ParenTIPS',
#   'Since 1952',
#   'WORLD',
#   "by Singapore Children's Society",
#   'Introduction',
#   'With the advent of social media, navigating the digital world safely and',
#   'appropriately has become an increasingly important skill. On one hand,',
#   'the digital world has exposed us to a plethora of media platforms and',
#   'communication mediums.',
#   'Then comes along the issue of freedom, for the problem emerges when',
#   'children and youth have difficulties differentiating between the right',
#   'level of freedom and safe navigation of the internet.',
#   'This might cause tension between them and their parents or caregivers',
#   'due to',
#   'OUR',
#   'DIGITAL',
#   'SOCIET',
#   'Podcast',
#   'Caring',
#   'for the',
#   'Future',
#   '70th',
#   'and',
#   'smiles',
#   'hope',
#   'ParenTIPS',
#   'Since',
#   '1952',
#   'WORLD',
#   'by',
#   'Singapore',
#   "Children's",
#   'Society',
#   'Introduction',
#   'With',
#   'the',
#   'advent',
#   'of',
#   'social',
#   'media,',
#   'navigating',
#   'the',
#   'digital',
#   'world',
#   'safely',
#   'and',
#   'appropriately',
#   'has',
#   'become',
#   'an',
#   'increasingly',
#   'important',
#   'skill.',
#   'On',
#   'one',
#   'hand,',
#   'the',
#   'digital',
#   'world',
#   'has',
#   'exposed',
#   'us',
#   'to',
#   'a',
#   'plethora',
#   'of',
#   'media',
#   'platforms',
#   'and',
#   'communication',
#   'mediums.',
#   'Then',
#   'comes',
#   'along',
#   'the',
#   'issue',
#   'of',
#   'freedom,',
#   'for',
#   'the',
#   'problem',
#   'emerges',
#   'when',
#   'children',
#   'and',
#   'youth',
#   'have',
#   'difficulties',
#   'differentiating',
#   'between',
#   'the',
#   'right',
#   'level',
#   'of',
#   'freedom',
#   'and',
#   'safe',
#   'navigation',
#   'of',
#   'the',
#   'internet.',
#   'This',
#   'might',
#   'cause',
#   'tension',
#   'between',
#   'them',
#   'and',
#   'their',
#   'parents',
#   'or',
#   'caregivers',
#   'due',
#   'to'],
#  ['What can children/youth do?',
#   '1) share your worries about the digital world',
#   'with parents/caregivers',
#   '2) set up a routine',
#   'e.g. switching off your phone 30 minutes',
#   'before sleeping',
#   '3) stay calm and seek help when necessary',
#   'e.g. if you are being cyber-bullied, do not',
#   'retaliate but instead tell a trusted adult first',
#   '4) remember that you have the support',
#   'of your parents/caregivers/friends',
#   "Copyright © 2022 Singapore Children's Society. All rights reserved.",
#   'What',
#   'can',
#   'children/youth',
#   'do?',
#   '1)',
#   'share',
#   'your',
#   'worries',
#   'about',
#   'the',
#   'digital',
#   'world',
#   'with',
#   'parents/caregivers',
#   '2)',
#   'set',
#   'up',
#   'a',
#   'routine',
#   'e.g.',
#   'switching',
#   'off',
#   'your',
#   'phone',
#   '30',
#   'minutes',
#   'before',
#   'sleeping',
#   '3)',
#   'stay',
#   'calm',
#   'and',
#   'seek',
#   'help',
#   'when',
#   'necessary',
#   'e.g.',
#   'if',
#   'you',
#   'are',
#   'being',
#   'cyber-bullied,',
#   'do',
#   'not',
#   'retaliate',
#   'but',
#   'instead',
#   'tell',
#   'a',
#   'trusted',
#   'adult',
#   'first',
#   '4)',
#   'remember',
#   'that',
#   'you',
#   'have',
#   'the',
#   'support',
#   'of',
#   'your',
#   'parents/caregivers/friends',
#   'Copyright',
#   '©',
#   '2022',
#   'Singapore',
#   "Children's",
#   'Society.',
#   'All',
#   'rights',
#   'reserved.'],
#  ['What can parents/caregivers do?',
#   '1) be a role model for children by setting a good',
#   'example and practising good habits',
#   '2) have conversations with your children to',
#   'have a better understanding about what they',
#   'are using their digital devices for',
#   '3) work out a family strategy together',
#   'e.g. set boundaries and expectations together,',
#   'what to do when things go wrong',
#   '4) enhance digital parenting knowledge through',
#   'online resources such as blogs and websites',
#   "Copyright © 2022 Singapore Children's Society. All rights reserved.",
#   'What',
#   'can',
#   'parents/caregivers',
#   'do?',
#   '1)',
#   'be',
#   'a',
#   'role',
#   'model',
#   'for',
#   'children',
#   'by',
#   'setting',
#   'a',
#   'good',
#   'example',
#   'and',
#   'practising',
#   'good',
#   'habits',
#   '2)',
#   'have',
#   'conversations',
#   'with',
#   'your',
#   'children',
#   'to',
#   'have',
#   'a',
#   'better',
#   'understanding',
#   'about',
#   'what',
#   'they',
#   'are',
#   'using',
#   'their',
#   'digital',
#   'devices',
#   'for',
#   '3)',
#   'work',
#   'out',
#   'a',
#   'family',
#   'strategy',
#   'together',
#   'e.g.',
#   'set',
#   'boundaries',
#   'and',
#   'expectations',
#   'together,',
#   'what',
#   'to',
#   'do',
#   'when',
#   'things',
#   'go',
#   'wrong',
#   '4)',
#   'enhance',
#   'digital',
#   'parenting',
#   'knowledge',
#   'through',
#   'online',
#   'resources',
#   'such',
#   'as',
#   'blogs',
#   'and',
#   'websites',
#   'Copyright',
#   '©',
#   '2022',
#   'Singapore',
#   "Children's",
#   'Society.',
#   'All',
#   'rights',
#   'reserved.'],
#  ["Children' 's",
#   'S OCIET',
#   'Caring for the Future',
#   '70 hope',
#   'and smiles',
#   'Since 1952',
#   'NEW',
#   'LUNAR',
#   'YEAR',
#   '2022',
#   'HAPPY',
#   'May the year of the Tiger bring you',
#   'happiness, prosperity, and many precious',
#   'moments with your loved ones.',
#   "Children'",
#   "'s",
#   'S',
#   'OCIET',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   '70',
#   'hope',
#   'and',
#   'smiles',
#   'Since',
#   '1952',
#   'NEW',
#   'LUNAR',
#   'YEAR',
#   '2022',
#   'HAPPY',
#   'May',
#   'the',
#   'year',
#   'of',
#   'the',
#   'Tiger',
#   'bring',
#   'you',
#   'happiness,',
#   'prosperity,',
#   'and',
#   'many',
#   'precious',
#   'moments',
#   'with',
#   'your',
#   'loved',
#   'ones.'],
#  [],
#  ['A LiTTLe KiNDNeSS,',
#   'LOTS OF JOY!',
#   'Children',
#   'LV OCIETY',
#   'of',
#   'bringing',
#   'hope',
#   'and smiles',
#   'Caring tor the Future',
#   'LUNAR NEW YEAR 2022',
#   'Since 1952',
#   'This Lunar new Year,',
#   'donate to our project',
#   '& fill the hearts of our beneficiaries',
#   'EUR',
#   'with extra love & joy.',
#   'Foster the value of giving',
#   '& get the little ones involved too!',
#   'Continue supporting us in making',
#   'a positive impact to our children,',
#   'youth, and families in need!',
#   'A',
#   'LiTTLe',
#   'KiNDNeSS,',
#   'LOTS',
#   'OF',
#   'JOY!',
#   'Children',
#   'LV',
#   'OCIETY',
#   'of',
#   'bringing',
#   'hope',
#   'and',
#   'smiles',
#   'Caring tor',
#   'the',
#   'Future',
#   'LUNAR',
#   'NEW',
#   'YEAR',
#   '2022',
#   'Since',
#   '1952',
#   'This',
#   'Lunar',
#   'new',
#   'Year,',
#   'donate',
#   'to',
#   'our',
#   'project',
#   '&',
#   'fill',
#   'the',
#   'hearts',
#   'of',
#   'our',
#   'beneficiaries',
#   'EUR',
#   'with',
#   'extra',
#   'love',
#   '&',
#   'joy.',
#   'Foster',
#   'the',
#   'value',
#   'of',
#   'giving',
#   '&',
#   'get',
#   'the',
#   'little',
#   'ones',
#   'involved',
#   'too!',
#   'Continue',
#   'supporting',
#   'us',
#   'in',
#   'making',
#   'a',
#   'positive',
#   'impact',
#   'to',
#   'our',
#   'children,',
#   'youth,',
#   'and',
#   'families',
#   'in',
#   'need!'],
#  ["Children's",
#   'and bringing smiles',
#   'hope',
#   'SOCIETY',
#   'Caring for the Future',
#   'Since 1952',
#   "Children's",
#   'and',
#   'bringing',
#   'smiles',
#   'hope',
#   'SOCIETY',
#   'Caring for',
#   'the',
#   'Future',
#   'Since',
#   '1952'],
#  ["Children's",
#   'SOCIETY',
#   'Caring for the Future',
#   '70 and',
#   'Since 1952',
#   'smiles hope',
#   'eur',
#   'EGGI',
#   'eur',
#   'GUT',
#   'ENGI',
#   'EGGI',
#   'EUR',
#   'EGGI',
#   "Children's",
#   'SOCIETY',
#   'Caring',
#   'for the Future',
#   '70',
#   'and',
#   'Since',
#   '1952',
#   'smiles',
#   'hope',
#   'eur',
#   'EGGI',
#   'eur',
#   'GUT',
#   'ENGI',
#   'EGGI',
#   'EUR',
#   'EGGI'],
#  ['years',
#   "Children's",
#   'of bringing hope',
#   'SOCIETY',
#   'and smiles',
#   'Caring for the Future',
#   'Since 1952',
#   'years',
#   "Children's",
#   'of',
#   'bringing',
#   'hope',
#   'SOCIETY',
#   'and',
#   'smiles',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   'Since',
#   '1952'],
#  ["Children's",
#   'Caring for the Future',
#   '70 and hope',
#   'smiles',
#   'Since 1952',
#   '50',
#   'Know someone who loves having',
#   'steamboat during Lunar New Year?',
#   'Send them this card to let them',
#   "know they're in your thoughts!",
#   "Children's",
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   '70',
#   'and',
#   'hope',
#   'smiles',
#   'Since',
#   '1952',
#   '50',
#   'Know',
#   'someone',
#   'who',
#   'loves',
#   'having',
#   'steamboat',
#   'during',
#   'Lunar',
#   'New',
#   'Year?',
#   'Send',
#   'them',
#   'this',
#   'card',
#   'to',
#   'let',
#   'them',
#   'know',
#   "they're",
#   'in',
#   'your',
#   'thoughts!'],
#  ["Children's",
#   'SOCIETY',
#   'Caring for the Future',
#   '70th and',
#   'smiles hope',
#   'Since 1952',
#   'Spread a little kindness this Lunar New Year',
#   '& donate to our project today!',
#   'A LiTTLe KiNDNeSS,',
#   'LOTS OF JOY!',
#   'LUNAR NEW YEAR 2022',
#   '104',
#   "Children's",
#   'SOCIETY',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   '70th',
#   'and',
#   'smiles',
#   'hope',
#   'Since',
#   '1952',
#   'Spread',
#   'a',
#   'little',
#   'kindness',
#   'this',
#   'Lunar',
#   'New',
#   'Year',
#   '&',
#   'donate',
#   'to',
#   'our',
#   'project',
#   'today!',
#   'A',
#   'LiTTLe',
#   'KiNDNeSS,',
#   'LOTS',
#   'OF',
#   'JOY!',
#   'LUNAR',
#   'NEW',
#   'YEAR',
#   '2022',
#   '104'],
#  ["Children's",
#   'SOCIETY',
#   '70 hope',
#   'and smiles',
#   'Caring for the Future',
#   'Since 1952',
#   'Spread a little kindness this Lunar New Year',
#   '& donate to our project today!',
#   'A LiTTLe KiNDNeSS,',
#   'LOTS OF JOY!',
#   '2022',
#   '04',
#   'A',
#   'ESSI',
#   'EGGI',
#   'Image credit: pexels.com',
#   "Children's",
#   'SOCIETY',
#   '70',
#   'hope',
#   'and',
#   'smiles',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   'Since',
#   '1952',
#   'Spread',
#   'a',
#   'little',
#   'kindness',
#   'this',
#   'Lunar',
#   'New',
#   'Year',
#   '&',
#   'donate',
#   'to',
#   'our',
#   'project',
#   'today!',
#   'A',
#   'LiTTLe',
#   'KiNDNeSS,',
#   'LOTS',
#   'OF',
#   'JOY!',
#   '2022',
#   '04',
#   'A',
#   'ESSI',
#   'EGGI',
#   'Image',
#   'credit:',
#   'pexels.com'],
#  ['First day of school', 'First', 'day', 'of', 'school'],
#  ["Children's SOCIET",
#   'Caring for the Future',
#   'Would you continue to bring hope and smiles',
#   'to our beneficiaries for many more years to come?',
#   'PAYM',
#   'Love',
#   '*Photos taken pre-COVID times',
#   "Children's",
#   'SOCIET',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   'Would',
#   'you',
#   'continue',
#   'to',
#   'bring',
#   'hope',
#   'and',
#   'smiles',
#   'to',
#   'our',
#   'beneficiaries',
#   'for',
#   'many',
#   'more',
#   'years',
#   'to',
#   'come?',
#   'PAYM',
#   'Love',
#   '*Photos',
#   'taken',
#   'pre-COVID',
#   'times'],
#  ["Children's",
#   'SOCIETY',
#   'Tips from the Experts',
#   'Caring for the Future',
#   'My new year resolution is to be kinder to my',
#   'loved ones but sometimes my nagging',
#   'parents really get on my nerves! How can I',
#   'keep the spirit of kindness to my loved ones?',
#   'It is commendable of you to set a resolution to show',
#   'kindness to people around you. Feeling annoyed when',
#   'being nagged at is perfectly normal; the important part',
#   'is how you manage it. How about changing',
#   "your perspective and see that your parents'",
#   'nagging is how they show their care and concern?',
#   'A perspective shift helps',
#   "Children's",
#   'SOCIETY',
#   'Tips',
#   'from',
#   'the',
#   'Experts',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   'My',
#   'new',
#   'year',
#   'resolution',
#   'is',
#   'to',
#   'be',
#   'kinder',
#   'to',
#   'my',
#   'loved',
#   'ones',
#   'but',
#   'sometimes',
#   'my',
#   'nagging',
#   'parents',
#   'really',
#   'get',
#   'on',
#   'my',
#   'nerves!',
#   'How',
#   'can',
#   'I',
#   'keep',
#   'the',
#   'spirit',
#   'of',
#   'kindness',
#   'to',
#   'my',
#   'loved',
#   'ones?',
#   'It',
#   'is',
#   'commendable',
#   'of',
#   'you',
#   'to',
#   'set',
#   'a',
#   'resolution',
#   'to',
#   'show',
#   'kindness',
#   'to',
#   'people',
#   'around',
#   'you.',
#   'Feeling',
#   'annoyed',
#   'when',
#   'being',
#   'nagged',
#   'at',
#   'is',
#   'perfectly',
#   'normal;',
#   'the',
#   'important',
#   'part',
#   'is',
#   'how',
#   'you',
#   'manage',
#   'it.',
#   'How',
#   'about',
#   'changing',
#   'your',
#   'perspective',
#   'and',
#   'see',
#   'that',
#   'your',
#   "parents'",
#   'nagging',
#   'is',
#   'how',
#   'they',
#   'show',
#   'their',
#   'care',
#   'and',
#   'concern?',
#   'A',
#   'perspective',
#   'shift',
#   'helps'],
#  ['Safe Haven: The first Latchkey Child Development',
#   'Centre, known as Children Centre, occupied three four-',
#   'room HDB flats in Block 94 Henderson Road. It was',
#   'officially opened on 2 April 1979',
#   'Safe',
#   'Haven:',
#   'The',
#   'first',
#   'Latchkey',
#   'Child',
#   'Development',
#   'Centre,',
#   'known',
#   'as',
#   'Children',
#   'Centre,',
#   'occupied',
#   'three',
#   'four-',
#   'room',
#   'HDB',
#   'flats',
#   'in',
#   'Block',
#   '94',
#   'Henderson',
#   'Road.',
#   'It',
#   'was',
#   'officially',
#   'opened',
#   'on',
#   '2',
#   'April',
#   '1979'],
#  ["Singapore Children's Society",
#   'Children',
#   "Student Care @ Children's Society",
#   'SOCIET',
#   'Carang for de Times',
#   'DREAM N Netccentric BIG',
#   "Present day: Student Care @ Children's Society at Blk 129",
#   'Bukit Merah View',
#   'Singapore',
#   "Children's",
#   'Society',
#   'Children',
#   'Student',
#   'Care',
#   "@ Children's",
#   'Society',
#   'SOCIET',
#   'Carang',
#   'for',
#   'de',
#   'Times',
#   'DREAM',
#   'N',
#   'Netccentric',
#   'BIG',
#   'Present',
#   'day:',
#   'Student',
#   'Care',
#   '@',
#   "Children's",
#   'Society',
#   'at',
#   'Blk',
#   '129',
#   'Bukit',
#   'Merah',
#   'View'],
#  ['Xinwei Fang',
#   'Wah Khoon',
#   'Snarina Roslan',
#   'Meng Hau',
#   'Khiaw Ngoh Tan',
#   'Nur Nadhirah',
#   'Quah Saw Han',
#   'Joyce Teng_SCS',
#   'Rong Q',
#   'Darwisyah&Umairah',
#   'Sue',
#   'Ada',
#   'KK',
#   'AMY~',
#   'Irdina Bharati',
#   'Cayden Woo',
#   'Bee Jop_Yishun Family Se',
#   'Vimala Ragavan',
#   'Hui Peng (SCS)',
#   'yinchen',
#   'Isabella Wong',
#   'Mats',
#   'Hac HOND',
#   'Year-end Party: SCC students and parents, staff and alumni',
#   'at the Zoom-based event',
#   'Xinwei',
#   'Fang',
#   'Wah',
#   'Khoon',
#   'Snarina',
#   'Roslan',
#   'Meng',
#   'Hau',
#   'Khiaw',
#   'Ngoh',
#   'Tan',
#   'Nur',
#   'Nadhirah',
#   'Quah',
#   'Saw',
#   'Han',
#   'Joyce',
#   'Teng_SCS',
#   'Rong',
#   'Q',
#   'Darwisyah&Umairah',
#   'Sue',
#   'Ada',
#   'KK',
#   'AMY~',
#   'Irdina',
#   'Bharati',
#   'Cayden',
#   'Woo',
#   'Bee',
#   'Jop_Yishun',
#   'Family',
#   'Se',
#   'Vimala',
#   'Ragavan',
#   'Hui',
#   'Peng',
#   '(SCS)',
#   'yinchen',
#   'Isabella',
#   'Wong',
#   'Mats',
#   'Hac',
#   'HOND',
#   'Year-end',
#   'Party:',
#   'SCC',
#   'students',
#   'and',
#   'parents,',
#   'staff',
#   'and',
#   'alumni',
#   'at',
#   'the',
#   'Zoom-based',
#   'event'],
#  ['SEWAGE',
#   '480380 .',
#   'B MAR APR MAY JUN JUL AUG SEP OCT NOV DEC',
#   'dina',
#   '-',
#   '-',
#   'Feeling: Paster',
#   'HELLO KITTY',
#   'Little scientists in action: Conducting experiments about air',
#   'and wind',
#   'SEWAGE',
#   '480380',
#   '.',
#   'B',
#   'MAR',
#   'APR',
#   'MAY',
#   'JUN',
#   'JUL',
#   'AUG',
#   'SEP',
#   'OCT',
#   'NOV',
#   'DEC',
#   'dina',
#   '-',
#   '-',
#   'Feeling:',
#   'Paster',
#   'HELLO',
#   'KITTY',
#   'Little',
#   'scientists',
#   'in',
#   'action:',
#   'Conducting',
#   'experiments',
#   'about',
#   'air',
#   'and',
#   'wind'],
#  ['OCO 100%',
#   "Making children's voices count: Sharing their lockdown",
#   "experiences at the 6th ASEAN Children's Forum",
#   'OCO',
#   '100%',
#   'Making',
#   "children's",
#   'voices',
#   'count:',
#   'Sharing',
#   'their',
#   'lockdown',
#   'experiences',
#   'at',
#   'the',
#   '6th',
#   'ASEAN',
#   "Children's",
#   'Forum'],
#  ['EXIT',
#   'makadadic',
#   'Exploring the world of colours: Our children at a painting',
#   'class',
#   'EXIT',
#   'makadadic',
#   'Exploring',
#   'the',
#   'world',
#   'of',
#   'colours:',
#   'Our',
#   'children',
#   'at',
#   'a',
#   'painting',
#   'class'],
#  ['NEVER',
#   'Farm to table learning: Getting hands on in the kitchen',
#   'garden',
#   'NEVER',
#   'Farm',
#   'to',
#   'table',
#   'learning:',
#   'Getting',
#   'hands',
#   'on',
#   'in',
#   'the',
#   'kitchen',
#   'garden'],
#  ["Children's",
#   'SOCIETY',
#   'Caring for the Future',
#   'Wishing you a very',
#   'Mung Christmas',
#   '& Happy New Year!',
#   'Love,',
#   "Singapore Children's Society",
#   "Children's",
#   'SOCIETY',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   'Wishing',
#   'you',
#   'a',
#   'very',
#   'Mung',
#   'Christmas',
#   '&',
#   'Happy',
#   'New',
#   'Year!',
#   'Love,',
#   'Singapore',
#   "Children's",
#   'Society'],
#  ['STRENGTHENING MENTAL HEALTH FOR',
#   'CHILDREN IS KEY IN BUILDING BACK BETTER',
#   "MAKING CHILDREN'S VOICES COUNT!",
#   'INVITATION TO',
#   'RECORD VIDEO',
#   'MESSAGES',
#   'Guide for Children',
#   'STRENGTHENING',
#   'MENTAL',
#   'HEALTH',
#   'FOR',
#   'CHILDREN',
#   'IS',
#   'KEY',
#   'IN',
#   'BUILDING',
#   'BACK',
#   'BETTER',
#   'MAKING',
#   "CHILDREN'S",
#   'VOICES',
#   'COUNT!',
#   'INVITATION',
#   'TO',
#   'RECORD',
#   'VIDEO',
#   'MESSAGES',
#   'Guide',
#   'for',
#   'Children'],
#  ["It isn't just an absence of mental",
#   'illness, being mentally well means',
#   'you can cope with normal',
#   'stresses, manage negative',
#   'emotions and feel good about',
#   'What is',
#   'yourself!',
#   'Good',
#   'Mental',
#   'Health?',
#   'It',
#   "isn't",
#   'just',
#   'an',
#   'absence',
#   'of',
#   'mental',
#   'illness,',
#   'being',
#   'mentally',
#   'well',
#   'means',
#   'you',
#   'can',
#   'cope',
#   'with',
#   'normal',
#   'stresses,',
#   'manage',
#   'negative',
#   'emotions',
#   'and',
#   'feel',
#   'good',
#   'about',
#   'What',
#   'is',
#   'yourself!',
#   'Good',
#   'Mental',
#   'Health?'],
#  ['In order for children to',
#   'have good mental health',
#   'They need to',
#   'have a good relationship with their',
#   'loved ones',
#   'have the freedom and time to play',
#   'be able to talk to people they trust',
#   'about their feelings',
#   'be a part of community activities or',
#   'a school that makes them feel like',
#   'they belong',
#   'In',
#   'order',
#   'for',
#   'children',
#   'to',
#   'have',
#   'good',
#   'mental',
#   'health',
#   'They',
#   'need',
#   'to',
#   'have',
#   'a',
#   'good',
#   'relationship',
#   'with',
#   'their',
#   'loved',
#   'ones',
#   'have',
#   'the',
#   'freedom',
#   'and',
#   'time',
#   'to',
#   'play',
#   'be',
#   'able',
#   'to',
#   'talk',
#   'to',
#   'people',
#   'they',
#   'trust',
#   'about',
#   'their',
#   'feelings',
#   'be',
#   'a',
#   'part',
#   'of',
#   'community',
#   'activities',
#   'or',
#   'a',
#   'school',
#   'that',
#   'makes',
#   'them',
#   'feel',
#   'like',
#   'they',
#   'belong'],
#  ['What worries you most about your',
#   '1',
#   "peers' mental health and/or",
#   'wellbeing?',
#   'What actions or projects have you done',
#   '2',
#   "(or your peers) to support others'",
#   'wellbeing and mental health needs before',
#   'and during the COVID-19 pandemic?',
#   'How',
#   'can',
#   'Your message will be shared with leaders',
#   'Recording a video',
#   'in government to help children be part of',
#   'you',
#   'responding to the',
#   'following',
#   '3',
#   'the solutions as we move into the recovery',
#   'contribute?',
#   'phase of COVID-19. What do you want to',
#   'questions:',
#   'tell them?',
#   'Your message will also be heard by other',
#   'children from other countries who are, like',
#   '4',
#   'you,',
#   'What',
#   'worries',
#   'you',
#   'most',
#   'about',
#   'your',
#   '1',
#   "peers'",
#   'mental',
#   'health',
#   'and/or',
#   'wellbeing?',
#   'What',
#   'actions',
#   'or',
#   'projects',
#   'have',
#   'you',
#   'done',
#   '2',
#   '(or',
#   'your',
#   'peers)',
#   'to',
#   'support',
#   "others'",
#   'wellbeing',
#   'and',
#   'mental',
#   'health',
#   'needs',
#   'before',
#   'and',
#   'during',
#   'the',
#   'COVID-19',
#   'pandemic?',
#   'How',
#   'can',
#   'Your',
#   'message',
#   'will',
#   'be',
#   'shared',
#   'with',
#   'leaders',
#   'Recording',
#   'a',
#   'video',
#   'in',
#   'government',
#   'to',
#   'help',
#   'children',
#   'be',
#   'part',
#   'of',
#   'you',
#   'responding',
#   'to',
#   'the',
#   'following',
#   '3',
#   'the',
#   'solutions',
#   'as',
#   'we',
#   'move',
#   'into',
#   'the',
#   'recovery',
#   'contribute?',
#   'phase',
#   'of',
#   'COVID-19.',
#   'What',
#   'do',
#   'you',
#   'want',
#   'to',
#   'questions:',
#   'tell',
#   'them?',
#   'Your',
#   'message',
#   'will',
#   'also',
#   'be',
#   'heard',
#   'by',
#   'other',
#   'children',
#   'from',
#   'other',
#   'countries',
#   'who',
#   'are,',
#   'like',
#   '4',
#   'you,'],
#  ['The Fun Part',
#   'How to',
#   'Place the phone in the horizontal',
#   'record the',
#   '1',
#   'position to answer the questions. It is ok',
#   'to make mistakes and repeat the',
#   'video',
#   'answers if you want. And you can',
#   'use your own language.',
#   'The',
#   'Fun',
#   'Part',
#   'How',
#   'to',
#   'Place',
#   'the',
#   'phone',
#   'in',
#   'the',
#   'horizontal',
#   'record',
#   'the',
#   '1',
#   'position',
#   'to',
#   'answer',
#   'the',
#   'questions.',
#   'It',
#   'is',
#   'ok',
#   'to',
#   'make',
#   'mistakes',
#   'and',
#   'repeat',
#   'the',
#   'video',
#   'answers',
#   'if',
#   'you',
#   'want.',
#   'And',
#   'you',
#   'can',
#   'use',
#   'your',
#   'own',
#   'language.'],
#  ['The Fun Part',
#   'How to',
#   'Please do NOT tell your last name when presenting yourself.',
#   'record the',
#   '"',
#   'Hello!',
#   'old',
#   'My',
#   'is',
#   'name',
#   'Dien,',
#   "I'm",
#   '13',
#   'and',
#   'years',
#   'am',
#   '2',
#   'from Vietnam.',
#   'video',
#   'think violence impacts the mental health of',
#   '"',
#   'children because...',
#   'Also, please record the video in a quiet place and do NOT',
#   'put background music on it.',
#   'The',
#   'Fun',
#   'Part',
#   'How',
#   'to',
#   'Please',
#   'do',
#   'NOT',
#   'tell',
#   'your',
#   'last',
#   'name',
#   'when',
#   'presenting',
#   'yourself.',
#   'record',
#   'the',
#   '"',
#   'Hello!',
#   'old',
#   'My',
#   'is',
#   'name',
#   'Dien,',
#   "I'm",
#   '13',
#   'and',
#   'years',
#   'am',
#   '2',
#   'from',
#   'Vietnam.',
#   'video',
#   'think',
#   'violence',
#   'impacts',
#   'the',
#   'mental',
#   'health',
#   'of',
#   '"',
#   'children',
#   'because...',
#   'Also,',
#   'please',
#   'record',
#   'the',
#   'video',
#   'in',
#   'a',
#   'quiet',
#   'place',
#   'and',
#   'do',
#   'NOT',
#   'put',
#   'background',
#   'music',
#   'on',
#   'it.'],
#  ['The Fun Part',
#   'How to',
#   'send the',
#   'Then, with the help of your',
#   '3',
#   'guardian/mentor, just send the video to',
#   'video',
#   'this email address: secretariat@crcasia.org',
#   'by 10 January 2022.',
#   'If the video is too heavy, please use www.wetransfer.com to send it to us!',
#   "Please don't forget to attach the consent form to the message.",
#   'The',
#   'Fun',
#   'Part',
#   'How',
#   'to',
#   'send',
#   'the',
#   'Then,',
#   'with',
#   'the',
#   'help',
#   'of',
#   'your',
#   '3',
#   'guardian/mentor,',
#   'just',
#   'send',
#   'the',
#   'video',
#   'to',
#   'video',
#   'this',
#   'email',
#   'address:',
#   'secretariat@crcasia.org',
#   'by',
#   '10',
#   'January',
#   '2022.',
#   'If',
#   'the',
#   'video',
#   'is',
#   'too',
#   'heavy,',
#   'please',
#   'use',
#   'www.wetransfer.com',
#   'to',
#   'send',
#   'it',
#   'to',
#   'us!',
#   'Please',
#   "don't",
#   'forget',
#   'to',
#   'attach',
#   'the',
#   'consent',
#   'form',
#   'to',
#   'the',
#   'message.'],
#  ['Jee', 'Jee'],
#  ['-',
#   'COOCOOTV',
#   'THANKYOULERONTLINERS',
#   '-',
#   'COOCOOTV',
#   'THANKYOULERONTLINERS'],
#  ["Let's Come Together for an Act of Love for our Children",
#   "Children's",
#   'SOCIETY',
#   'Caring for the Future',
#   'DONATION DRAW 2021',
#   "SINGAPORE CHILDREN'S SOCIETY",
#   'Winning Numbers',
#   '1 st Prize:',
#   '24575',
#   '11th Prize:',
#   '17064',
#   '2nd Prize:',
#   '20638',
#   '12th Prize:',
#   '17221',
#   '3rd Prize:',
#   '21164',
#   '13th Prize:',
#   '15903',
#   '4th Prize:',
#   '18473',
#   '14th Prize:',
#   '21222',
#   '5th Prize:',
#   '11501',
#   '15th Prize:',
#   '15594',
#   '6th Prize:',
#   '18759',
#   '16th Prize:',
#   '18668',
#   '7th Prize:',
#   '20966',
#   '17th Prize:',
#   '12310',
#   '8th Prize:',
#   '18th Prize:',
#   '18633',
#   '14100',
#   '9th Prize:',
#   '18003',
#   '19th Prize:',
#   '01243',
#   '10th Prize:',
#   '20th Prize:',
#   '13812',
#   '21741',
#   'Collection details:',
#   '1. All prizes must be collected between Monday, 27 December 2021 and',
#   "Let's",
#   'Come',
#   'Together',
#   'for',
#   'an',
#   'Act',
#   'of',
#   'Love',
#   'for',
#   'our',
#   'Children',
#   "Children's",
#   'SOCIETY',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   'DONATION',
#   'DRAW',
#   '2021',
#   'SINGAPORE',
#   "CHILDREN'S",
#   'SOCIETY',
#   'Winning',
#   'Numbers',
#   '1',
#   'st',
#   'Prize:',
#   '24575',
#   '11th',
#   'Prize:',
#   '17064',
#   '2nd',
#   'Prize:',
#   '20638',
#   '12th',
#   'Prize:',
#   '17221',
#   '3rd',
#   'Prize:',
#   '21164',
#   '13th',
#   'Prize:',
# ...
#   'inner',
#   '2019',
#   'Tuesday,',
#   '19',
#   'March',
#   '2019',
#   'Guest',
#   'of',
#   'Honour',
#   'MR',
#   'TEO',
#   'CHEE',
#   'HEAN',
#   'ister',
#   '&',
#   'Coordinating',
#   'Minister',
#   'for',
#   'National',
#   'Security',
#   'erprises',
#   'and',
#   '1000',
#   'Philanthropists',
#   'for',
#   'Children-in-Need',
#   'tote',
#   'Society',
#   'of',
#   'board',
#   'Project',
#   'SHRI',
#   'Managers',
#   'Giving',
#   'Hope',
#   'Singapore',
#   'Pransing',
#   'there',
#   'Capital',
#   'Improving',
#   'Lives'],
#  [],
#  ['00 Philanthropists for Children-in-Need',
#   'reciation',
#   'Dinner 2',
#   'Tuesday, 19',
#   'Guest of Honour',
#   'MR TEO CHEE H',
#   'ter & Coordinating Min',
#   'hyla.ch-in-Ne',
#   'rises and 1000 Philanth',
#   'tote',
#   'SPN s',
#   'board',
#   'SHRI',
#   'Giving Hope',
#   'Powering Human Capital',
#   'Improving Lives',
#   '00',
#   'Philanthropists',
#   'for',
#   'Children-in-Need',
#   'reciation',
#   'Dinner',
#   '2',
#   'Tuesday,',
#   '19',
#   'Guest',
#   'of',
#   'Honour',
#   'MR',
#   'TEO',
#   'CHEE',
#   'H',
#   'ter',
#   '&',
#   'Coordinating',
#   'Min',
#   'hyla.ch-in-Ne',
#   'rises',
#   'and',
#   '1000',
#   'Philanth',
#   'tote',
#   'SPN',
#   's',
#   'board',
#   'SHRI',
#   'Giving',
#   'Hope',
#   'Powering',
#   'Human',
#   'Capital',
#   'Improving',
#   'Lives'],
#  ['1000',
#   'ENTER',
#   '-',
#   '1000 Enterprises and 1000 Philanthropists for Children-in-Need',
#   'April T',
#   'ion',
#   'r',
#   '2010',
#   '19 March',
#   'Depail',
#   'Patron',
#   '1000',
#   'ENTER',
#   '-',
#   '1000',
#   'Enterprises',
#   'and',
#   '1000',
#   'Philanthropists',
#   'for',
#   'Children-in-Need',
#   'April',
#   'T',
#   'ion',
#   'r',
#   '2010',
#   '19',
#   'March',
#   'Depail',
#   'Patron'],
#  ['HAPPY SOCIAL',
#   'WORKER DAY!',
#   'A work of heart: Social workers enhance and',
#   'enrich the lives of others',
#   'HAPPY',
#   'SOCIAL',
#   'WORKER',
#   'DAY!',
#   'A',
#   'work',
#   'of',
#   'heart:',
#   'Social',
#   'workers',
#   'enhance',
#   'and',
#   'enrich',
#   'the',
#   'lives',
#   'of',
#   'others'],
#  ["Children's",
#   'SOCIETY',
#   'Caring for the Future',
#   'G2C',
#   'Support the growth and future of our',
#   'children, youth and families in need',
#   "Children's",
#   'SOCIETY',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   'G2C',
#   'Support',
#   'the',
#   'growth',
#   'and',
#   'future',
#   'of',
#   'our',
#   'children,',
#   'youth',
#   'and',
#   'families',
#   'in',
#   'need'],
#  ['HAPPY',
#   "INTERNATIONAL WOMEN'S DAY",
#   'HAPPY',
#   'INTERNATIONAL',
#   "WOMEN'S",
#   'DAY'],
#  ['IN #1:',
#   'CHOICE OF. MAIN #2:',
#   'Come',
#   'VOX',
#   'KEN',
#   'DESS',
#   'CHOP',
#   'a',
#   'FISH',
#   'W/ F FRIES',
#   '+',
#   '&',
#   'in',
#   'PS',
#   'REE',
#   'Ofea',
#   'Ralons',
#   'VOX',
#   'BE',
#   'RDI',
#   'HEARD',
#   'PING AN GREEN',
#   'IN',
#   '#1:',
#   'CHOICE',
#   'OF.',
#   'MAIN',
#   '#2:',
#   'Come',
#   'VOX',
#   'KEN',
#   'DESS',
#   'CHOP',
#   'a',
#   'FISH',
#   'W/',
#   'F',
#   'FRIES',
#   '+',
#   '&',
#   'in',
#   'PS',
#   'REE',
#   'Ofea',
#   'Ralons',
#   'VOX',
#   'BE',
#   'RDI',
#   'HEARD',
#   'PING',
#   'AN',
#   'GREEN'],
#  ['SINPLY',
#   'APPROACH',
#   'no cooking enter 4.10pm &',
#   'SOCIAL-WEAR',
#   'ARP PASSPY',
#   'revender ergheen when e wor',
#   'PHONE KEF',
#   'Titdl',
#   'ACTIVATIVO',
#   'COOKING',
#   'PESSIONI',
#   'mas',
#   'VOX AF',
#   'SINPLY',
#   'APPROACH',
#   'no',
#   'cooking',
#   'enter',
#   '4.10pm &',
#   'SOCIAL-WEAR',
#   'ARP',
#   'PASSPY',
#   'revender',
#   'ergheen',
#   'when',
#   'e wor',
#   'PHONE',
#   'KEF',
#   'Titdl',
#   'ACTIVATIVO',
#   'COOKING',
#   'PESSIONI',
#   'mas',
#   'VOX',
#   'AF'],
#  ['AND PASS Your',
#   'year',
#   'o',
#   'ACTIVATING PHONE BEFORE',
#   'EDI',
#   'COOKING',
#   'SEEGION',
#   'TEAT',
#   'I',
#   'VOX',
#   'DE',
#   'AND',
#   'PASS',
#   'Your',
#   'year',
#   'o',
#   'ACTIVATING',
#   'PHONE',
#   'BEFORE',
#   'EDI',
#   'COOKING',
#   'SEEGION',
#   'TEAT',
#   'I',
#   'VOX',
#   'DE'],
#  ['VOX fiesta2010', 'VOX', 'fiesta2010'],
#  ['Children', 'SOCIETY', 'Children', 'SOCIETY'],
#  ['ا', 'ا'],
#  ['Coca-Cola', '- -', 'Charte', 'Coca-Cola', '-', '-', 'Charte'],
#  ['Vulnerable Children & Youth',
#   "Children's",
#   'SOCIETY',
#   'Caring for the Future',
#   'Research & Advocacy',
#   'Children & Youth Services',
#   'Family Services',
#   'Vulnerable',
#   'Children',
#   '&',
#   'Youth',
#   "Children's",
#   'SOCIETY',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   'Research',
#   '&',
#   'Advocacy',
#   'Children',
#   '&',
#   'Youth',
#   'Services',
#   'Family',
#   'Services'],
#  ['VOX', 'BE', 'HEARD', 'VOX', 'BE', 'HEARD'],
#  ['-',
#   'Tomato',
#   'Sura',
#   'سلسلة مؤسسة',
#   'Executive ط C',
#   '-',
#   'Tomato',
#   'Sura',
#   'سلسلة',
#   'مؤسسة',
#   'Executive',
#   'ط',
#   'C'],
#  ['UNTER ana 90.066/',
#   'N.00966 LOUSIANA',
#   'NEW ORILEANS',
#   'FOR 19978',
#   'UNTER',
#   'ana',
#   '90.066/',
#   'N.00966',
#   'LOUSIANA',
#   'NEW',
#   'ORILEANS',
#   'FOR',
#   '19978'],
#  ['LABO',
#   'I HB',
#   'ota kcal',
#   'blind',
#   '20CIF',
#   'LABO',
#   'I',
#   'HB',
#   'ota',
#   'kcal',
#   'blind',
#   '20CIF'],
#  ['Singapore Children',
#   'Sunbeam Pla',
#   'TE',
#   'Singapore',
#   'Children',
#   'Sunbeam',
#   'Pla',
#   'TE'],
#  ['western', 'classic', 'western', 'classic'],
#  ['DEEP FI',
#   'ESPRI',
#   'SAN FRAY',
#   'CALIFORNIA',
#   'SINCE',
#   '1968',
#   'I S',
#   'E I a',
#   'How',
#   '5',
#   'qued',
#   'Rzzrre',
#   'IDEN',
#   'LUM San',
#   'I',
#   'FNA',
#   ':',
#   'your',
#   'This',
#   'KS',
#   'B',
#   '5',
#   'cually',
#   'DASS',
#   'DEEP',
#   'FI',
#   'ESPRI',
#   'SAN',
#   'FRAY',
#   'CALIFORNIA',
#   'SINCE',
#   '1968',
#   'I',
#   'S',
#   'E',
#   'I',
#   'a',
#   'How',
#   '5',
#   'qued',
#   'Rzzrre',
#   'IDEN',
#   'LUM',
#   'San',
#   'I',
#   'FNA',
#   ':',
#   'your',
#   'This',
#   'KS',
#   'B',
#   '5',
#   'cually',
#   'DASS'],
#  ['-', 'mm', 'ONTE', '-', 'mm', 'ONTE'],
#  ['"IN FAMILY LIFE, LOVE',
#   'MSU',
#   'IS THE OIL THAT',
#   'EASES FRICTION, THE',
#   'CEMENT THAT BINDS',
#   'CLOSER TOGETHER,',
#   'AND THE MUSIC THAT',
#   'BRINGS HARMONY."',
#   '- FRIEDRICH NIETZCHE',
#   '-',
#   '% e',
#   '"IN',
#   'FAMILY',
#   'LIFE,',
#   'LOVE',
#   'MSU',
#   'IS',
#   'THE',
#   'OIL',
#   'THAT',
#   'EASES',
#   'FRICTION,',
#   'THE',
#   'CEMENT',
#   'THAT',
#   'BINDS',
#   'CLOSER',
#   'TOGETHER,',
#   'AND',
#   'THE',
#   'MUSIC',
#   'THAT',
#   'BRINGS',
#   'HARMONY."',
#   '- FRIEDRICH',
#   'NIETZCHE',
#   '-',
#   '%',
#   'e'],
#  ['DIVERGENCE',
#   '+ ore',
#   'ITERANCE',
#   'DIPMIX',
#   'DIVIDGING',
#   '-NO ES',
#   'TERGENCE',
#   'UKI 089',
#   '-',
#   'DIVERGENCE',
#   '+',
#   'ore',
#   'ITERANCE',
#   'DIPMIX',
#   'DIVIDGING',
#   '-NO',
#   'ES',
#   'TERGENCE',
#   'UKI',
#   '089',
#   '-'],
#  ['Danny',
#   'WALK for',
#   'CHILDR',
#   '018',
#   'uvin',
#   'DIRR',
#   'LIVINGENCE',
#   'GENE',
#   '20cLN',
#   'AVERGENCY',
#   'LESCE an-',
#   'OF-HONG',
#   'LAND FESTER',
#   'WEE',
#   'WOH HUP',
#   'FOR FIN',
#   'Danny',
#   'WALK',
#   'for',
#   'CHILDR',
#   '018',
#   'uvin',
#   'DIRR',
#   'LIVINGENCE',
#   'GENE',
#   '20cLN',
#   'AVERGENCY',
#   'LESCE',
#   'an-',
#   'OF-HONG',
#   'LAND',
#   'FESTER',
#   'WEE',
#   'WOH',
#   'HUP',
#   'FOR',
#   'FIN'],
#  ['Organization',
#   'HISCO',
#   'tote book',
#   'WALK FOR',
#   'ation',
#   'iren',
#   'lan ead',
#   'OUR CHILDREN',
#   'La',
#   '2018',
#   'VIRGENT',
#   'III',
#   'DIVERGENCE',
#   'HYERGENCI',
#   'und 00',
#   'CHANCE',
#   '+ I',
#   '-',
#   '-HONOUR',
#   'THE',
#   'GUES',
#   'oly',
#   'VEE KEAT',
#   'MR HEN',
#   'M',
#   'G',
#   'FINANCE',
#   'MINIST',
#   'в',
#   's',
#   'Organization',
#   'HISCO',
#   'tote',
#   'book',
#   'WALK',
#   'FOR',
#   'ation',
#   'iren',
#   'lan',
#   'ead',
#   'OUR',
#   'CHILDREN',
#   'La',
#   '2018',
#   'VIRGENT',
#   'III',
#   'DIVERGENCE',
#   'HYERGENCI',
#   'und',
#   '00',
#   'CHANCE',
#   '+',
#   'I',
#   '-',
#   '-HONOUR',
#   'THE',
#   'GUES',
#   'oly',
#   'VEE',
#   'KEAT',
#   'MR',
#   'HEN',
#   'M',
#   'G',
#   'FINANCE',
#   'MINIST',
#   'в',
#   's'],
#  ['Dear children Society',
#   'B be Strong and Smile',
#   'always',
#   'ADMPS',
#   'Jolin',
#   'Dear',
#   'children',
#   'Society',
#   'B',
#   'be',
#   'Strong',
#   'and',
#   'Smile',
#   'always',
#   'ADMPS',
#   'Jolin'],
#  ['If',
#   'you are reading this, coll them I say hi and',
#   'I tell',
#   'them to be positive "',
#   '- Oniyn',
#   'If',
#   'you',
#   'are',
#   'reading',
#   'this,',
#   'coll',
#   'them',
#   'I say',
#   'hi',
#   'and',
#   'I',
#   'tell',
#   'them',
#   'to',
#   'be',
#   'positive',
#   '"',
#   '- Oniyn'],
#  ['Mummy,',
#   'will you be back this',
#   'Chinese New Year?',
#   'Mummy,',
#   'will',
#   'you',
#   'be',
#   'back',
#   'this',
#   'Chinese',
#   'New',
#   'Year?'],
#  ['- am UN donori',
#   'i',
#   '-',
#   '-',
#   '-',
#   'علده - - 1',
#   'مجمة -',
#   'Eva I Cheer',
#   '-',
#   '? made - chad smiler',
#   'LICHERS',
#   '-',
#   'jharm-l',
#   'J /',
#   "Children's",
#   'SOCIETY',
#   'Caring for the Future',
#   '-',
#   'am',
#   'UN',
#   'donori',
#   'i',
#   '-',
#   '-',
#   '-',
#   'علده',
#   '-',
#   '-',
#   '1',
#   'مجمة',
#   '-',
#   'Eva',
#   'I',
#   'Cheer',
#   '-',
#   '?',
#   'made',
#   '-',
#   'chad',
#   'smiler',
#   'LICHERS',
#   '-',
#   'jharm-l',
#   'J',
#   '/',
#   "Children's",
#   'SOCIETY',
#   'Caring',
#   'for',
#   'the',
#   'Future'],
#  ['HAPPY LUNAR NEW YEAR!',
#   "Children's",
#   'SOCIETY',
#   'Caring for the Future',
#   'May this coming year overflow with',
#   'happiness, prosperity, good health and good luck.',
#   'HAPPY',
#   'LUNAR',
#   'NEW',
#   'YEAR!',
#   "Children's",
#   'SOCIETY',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   'May',
#   'this',
#   'coming',
#   'year',
#   'overflow',
#   'with',
#   'happiness,',
#   'prosperity,',
#   'good',
#   'health',
#   'and',
#   'good',
#   'luck.'],
#  ['2019',
#   '2019',
#   'May you have good fortune,',
#   '2019',
#   '2019',
#   'May',
#   'you',
#   'have',
#   'good',
#   'fortune,'],
#  ['DOCTOR',
#   'TEACHER',
#   'ACTOR',
#   'COOK',
#   'LAWYER',
#   'DOCTOR',
#   'TEACHER',
#   'ACTOR',
#   'COOK',
#   'LAWYER'],
#  ['Looking for tips to enhance',
#   "your child's well-being?",
#   "Children's",
#   'SOCIETY',
#   'Caring for the Future',
#   'Our Parenting Guides can help!',
#   "Children's",
#   '$3',
#   'per copy*',
#   "Children's",
#   'Parenting Guide',
#   'on Toddlers',
#   'PARENTING GUIDE',
#   'by',
#   'ON BABIES',
#   "Singapore Children's Society",
#   'Babies (Birth - 1 year old)',
#   'Toddlers (1 year old - 3 years old)',
#   'Available in English and Malay',
#   'Available in English',
#   'Colleg the',
#   'For more information, please contact US',
#   "Singapore Children's Society",
#   'info@childrensociety.org.sg | Tel: 6358 0911',
#   '*additional fees apply for postage',
#   'PARENTING GUIDE',
#   'ON PRE-SCHOOLERS',
#   'Pre-schoolers (4 years old - 6 years old)',
#   'Available in English, Chinese, and Malay',
#   'Looking',
#   'for',
#   'tips',
#   'to',
#   'enhance',
#   'your',
#   "child's",
#   'well-being?',
#   "Children's",
#   'SOCIETY',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   'Our',
#   'Parenting',
#   'Guides',
#   'can',
#   'help!',
#   "Children's",
#   '$3',
#   'per',
#   'copy*',
#   "Children's",
#   'Parenting',
#   'Guide',
#   'on',
#   'Toddlers',
#   'PARENTING',
#   'GUIDE',
#   'by',
#   'ON',
#   'BABIES',
#   'Singapore',
#   "Children's",
#   'Society',
#   'Babies',
#   '(Birth - 1',
#   'year',
#   'old)',
#   'Toddlers',
#   '(1',
#   'year',
#   'old - 3',
#   'years',
#   'old)',
#   'Available',
#   'in',
#   'English',
#   'and',
#   'Malay',
#   'Available',
#   'in',
#   'English',
#   'Colleg the',
#   'For',
#   'more',
#   'information,',
#   'please',
#   'contact',
#   'US',
#   'Singapore',
#   "Children's",
#   'Society',
#   'info@childrensociety.org.sg',
#   '|',
#   'Tel:',
#   '6358',
#   '0911',
#   '*additional',
#   'fees',
#   'apply',
#   'for',
#   'postage',
#   'PARENTING',
#   'GUIDE',
#   'ON',
#   'PRE-SCHOOLERS',
#   'Pre-schoolers',
#   '(4',
#   'years',
#   'old - 6',
#   'years',
#   'old)',
#   'Available',
#   'in',
#   'English,',
#   'Chinese,',
#   'and',
#   'Malay'],
#  [],
#  ['IF YOU ENJOY CHATTING WITH',
#   'CHILDREN AND HAVE EXPERIENCE',
#   'INTERACTING WITH CHILDREN, WE',
#   'WANT YOU!',
#   'Volunteer to be a Tinkle Friend',
#   'now!',
#   'Tinhle Triend-1800 2744 788',
#   'www.linktefriend.ag',
#   'IF',
#   'YOU',
#   'ENJOY',
#   'CHATTING',
#   'WITH',
#   'CHILDREN',
#   'AND',
#   'HAVE',
#   'EXPERIENCE',
#   'INTERACTING',
#   'WITH',
#   'CHILDREN,',
#   'WE',
#   'WANT',
#   'YOU!',
#   'Volunteer',
#   'to',
#   'be',
#   'a',
#   'Tinkle',
#   'Friend',
#   'now!',
#   'Tinhle',
#   'Triend-1800',
#   '2744',
#   '788',
#   'www.linktefriend.ag'],
#  ['Tinkle Friend - 1800 2744 788',
#   'www.tinklefriend.sg',
#   'Tinkle',
#   'Friend - 1800',
#   '2744',
#   '788',
#   'www.tinklefriend.sg'],
#  ['FILMAL',
#   'BEEN WAITING FOR THE PERFECT OPPORTUNITY TO',
#   'VOLUNTEER AND INTERACT WITH CHILDREN?',
#   'WE ARE LOOKING FOR CHOO CHOO TRAIN',
#   'PROGRAMME VOLUNTEERS!',
#   'FILMAL',
#   'BEEN',
#   'WAITING',
#   'FOR',
#   'THE',
#   'PERFECT',
#   'OPPORTUNITY',
#   'TO',
#   'VOLUNTEER',
#   'AND',
#   'INTERACT',
#   'WITH',
#   'CHILDREN?',
#   'WE',
#   'ARE',
#   'LOOKING',
#   'FOR',
#   'CHOO',
#   'CHOO',
#   'TRAIN',
#   'PROGRAMME',
#   'VOLUNTEERS!'],
#  ['TANGS',
#   '72"ANNIVE',
#   '14',
#   'SAMPLE',
#   '$1100',
#   '95%',
#   'People',
#   'CANS',
#   'zup',
#   'FREE',
#   'I',
#   'Calle',
#   '18',
#   'Templose Contrat',
#   'Community Complex',
#   '30',
#   'ck up & save',
#   '15 Dogo',
#   '5330',
#   'Buyends',
#   'Rose',
#   '050g',
#   'fo',
#   'zahari',
#   'day',
#   'a 2',
#   'foguita',
#   'THE',
#   'The C',
#   'Save 190',
#   'H. sols',
#   'the',
#   'Gauret Etan G',
#   'UN itself',
#   'SEDS',
#   'ES',
#   'aminiment',
#   '5890',
#   '3 in T',
#   'is 58',
#   'rorism',
#   'C',
#   '14 J',
#   'state to',
#   'i',
#   'B',
#   '14',
#   'on.',
#   '5,955',
#   'I',
#   'ER',
#   '$2.55',
#   '$1645',
#   'and SS 5',
#   '534553',
#   'RUST REACTS',
#   'the',
#   'R.V.P.C',
#   'Strakes',
#   'to',
#   'Parky',
#   'lash',
#   'not de',
#   '12%',
#   'Sale 18',
#   '5315',
#   'The Colour Circle',
#   '$235',
#   '3:',
#   'Seve 17',
#   'the',
#   'UP TO',
#   '$2.55',
#   '00',
#   '$185',
#   'II',
#   '85',
#   'Primary',
#   'FFF',
#   'TANGS',
#   '72"ANNIVE',
#   '14',
#   'SAMPLE',
#   '$1100',
#   '95%',
#   'People',
#   'CANS',
#   'zup',
#   'FREE',
#   'I',
#   'Calle',
#   '18',
#   'Templose',
#   'Contrat',
#   'Community',
#   'Complex',
#   '30',
#   'ck',
#   'up',
#   '&',
#   'save',
#   '15',
#   'Dogo',
#   '5330',
#   'Buyends',
#   'Rose',
#   '050g',
#   'fo',
#   'zahari',
#   'day',
#   'a',
#   '2',
#   'foguita',
#   'THE',
#   'The C',
#   'Save',
#   '190',
#   'H.',
#   'sols',
#   'the',
#   'Gauret',
#   'Etan',
#   'G',
#   'UN itself',
#   'SEDS',
#   'ES',
#   'aminiment',
#   '5890',
#   '3 in T',
#   'is',
#   '58',
#   'rorism',
#   'C',
#   '14',
#   'J',
#   'state to',
#   'i',
#   'B',
#   '14',
#   'on.',
#   '5,955',
#   'I',
#   'ER',
#   '$2.55',
#   '$1645',
#   'and',
#   'SS',
#   '5',
#   '534553',
#   'RUST',
#   'REACTS',
#   'the',
#   'R.V.P.C',
#   'Strakes',
#   'to',
#   'Parky',
#   'lash',
#   'not',
#   'de',
#   '12%',
#   'Sale',
#   '18',
#   '5315',
#   'The',
#   'Colour',
#   'Circle',
#   '$235',
#   '3:',
#   'Seve',
#   '17',
#   'the',
#   'UP TO',
#   '$2.55',
#   '00',
#   '$185',
#   'II',
#   '85',
#   'Primary',
#   'FFF'],
#  ['L',
#   'Rules for Volunteers',
#   'Rules in the',
#   'WORLD',
#   'DAY',
#   'League',
#   'MARY',
#   'SC',
#   'ZHANGJE',
#   'L',
#   'Rules',
#   'for',
#   'Volunteers',
#   'Rules',
#   'in the',
#   'WORLD',
#   'DAY',
#   'League',
#   'MARY',
#   'SC',
#   'ZHANGJE'],
#  [],
#  ['Approach the',
#   'New Year with',
#   'resolve to find the',
#   'opportunities',
#   'hidden in each day',
#   'Michael Josephson',
#   'Approach',
#   'the',
#   'New',
#   'Year',
#   'with',
#   'resolve',
#   'to',
#   'find',
#   'the',
#   'opportunities',
#   'hidden',
#   'in',
#   'each',
#   'day',
#   'Michael',
#   'Josephson'],
#  ['Wehopeall the best',
#   'for you ن Smile',
#   'Here is $2 for you.',
#   'From Gnang Hong (8 years olds',
#   'To: Somebody',
#   'Wehopeall',
#   'the',
#   'best',
#   'for you ن',
#   'Smile',
#   'Here',
#   'is',
#   '$2',
#   'for',
#   'you.',
#   'From',
#   'Gnang',
#   'Hong',
#   '(8',
#   'years',
#   'olds',
#   'To:',
#   'Somebody'],
#  ['ORGANISED BY',
#   'VENUE PARTNER',
#   "Children's",
#   'YOUTH CORPS',
#   'SOCIETY',
#   'SINGAPORE',
#   'Caring for the Future',
#   "SINGAPORE CHILDREN'S SOCIETY",
#   'FLAG DAY 2019!',
#   'SIGN UP',
#   'NOW!',
#   'Saturday, 30 March 2019',
#   'ORGANISED',
#   'BY',
#   'VENUE',
#   'PARTNER',
#   "Children's",
#   'YOUTH',
#   'CORPS',
#   'SOCIETY',
#   'SINGAPORE',
#   'Caring',
#   'for',
#   'the',
#   'Future',
#   'SINGAPORE',
#   "CHILDREN'S",
#   'SOCIETY',
#   'FLAG',
#   'DAY',
#   '2019!',
#   'SIGN',
#   'UP',
#   'NOW!',
#   'Saturday,',
#   '30',
#   'March',
#   '2019'],
#  ['I',
#   'to',
#   'SHIFTS',
#   'AVAILABLE',
#   'AM: 9am-1pm',
#   'SATURDAY',
#   'PM: 1pm-5pm',
#   'Full: 9am-5pm',
#   '30 MARCH',
#   'VENUE',
#   'The Red Box, 113 Somerset Road',
#   'Singapore 238165',
#   'Nearest MRT: Somerset',
#   '-',
#   'B',
#   'I',
#   'to',
#   'SHIFTS',
#   'AVAILABLE',
#   'AM:',
#   '9am-1pm',
#   'SATURDAY',
#   'PM:',
#   '1pm-5pm',
#   'Full:',
#   '9am-5pm',
#   '30',
#   'MARCH',
#   'VENUE',
#   'The',
#   'Red',
#   'Box,',
#   '113',
#   'Somerset',
#   'Road',
#   'Singapore',
#   '238165',
#   'Nearest',
#   'MRT:',
#   'Somerset',
#   '-',
#   'B'],
#  ['FDE', 'FDE'],
#  ...]

# %%
len(text_all)
# Out:
# 1481

# %%
df['labels'] = text_all
# df['labels'] = df['labels'].apply(lambda x: literal_eval(x))
df["labels_str"] = df['labels'].apply(' '.join)
df = df[['postUrl','commentCount', 'likeCount', 'description', 'labels', 'labels_str']]
df.head(10)
# Out:
#                                     postUrl  commentCount  likeCount  \
# 0  https://www.instagram.com/p/CbzXkYBsSZ0/             0         12
# 1  https://www.instagram.com/p/CbhK4IQKwcd/             1         36
# 2  https://www.instagram.com/p/CbeksJWrCPZ/             0         46
# 3  https://www.instagram.com/p/CbeksJWrCPZ/             0         46
# 4  https://www.instagram.com/p/CbeksJWrCPZ/             0         46
# 5  https://www.instagram.com/p/CbeksJWrCPZ/             0         46
# 6  https://www.instagram.com/p/CbeksJWrCPZ/             0         46
# 7  https://www.instagram.com/p/CbZBDq6rRnv/             0         38
# 8  https://www.instagram.com/p/CbW1HoSrDt0/             0         41
# 9  https://www.instagram.com/p/CbHbKk2rDGb/             1         73
#
#                                          description  \
# 0  Happy 1st April! This means that… Our Virtual ...
# 1  👀 Take a peep into #adayinthelife of a youth w...
# 2  Singapore Children’s Society held the 1000 Ent...
# 3  Singapore Children’s Society held the 1000 Ent...
# 4  Singapore Children’s Society held the 1000 Ent...
# 5  Singapore Children’s Society held the 1000 Ent...
# 6  Singapore Children’s Society held the 1000 Ent...
# 7  Today is World Water Day. To raise awareness a...
# 8  “Hello, I’m Tinkle Friend! What would you like...
# 9  It is World Social Work Day today! We invited ...
#
#                                               labels  \
# 0  [Children 'sv, SOCIET, Caring for the Futuro, ...
# 1  [A Day in the, Life of a Youth, Worker From, j...
# 2  [-, 70ml and, ENTERPRISES, 1000 ENTERPRISES FO...
# 3  [ENTE, 1000 ENTERPRISES FOR CHILDREN-IN-NEED, ...
# 4                                                 []
# 5  [1000 ENTERPRISES FOR CHILDREN-IN-NEED, ENTERP...
# 6  [years, Children, ozime hope, SOCIET, Canno fo...
# 7  [MAKE, SINGA, EVERY, لله, TTR, TYR, CA4458 fee...
# 8  [y-Free, -, Onion, -, WA, -, - -, Need someone...
# 9  [Bee Joo (the one squatting down), our staff a...
#
#                                           labels_str
# 0  Children 'sv SOCIET Caring for the Futuro 7a a...
# 1  A Day in the Life of a Youth Worker From jyc @...
# 2  - 70ml and ENTERPRISES 1000 ENTERPRISES FOR CH...
# 3  ENTE 1000 ENTERPRISES FOR CHILDREN-IN-NEED CHI...
# 4
# 5  1000 ENTERPRISES FOR CHILDREN-IN-NEED ENTERPRI...
# 6  years Children ozime hope SOCIET Canno for the...
# 7  MAKE SINGA EVERY لله TTR TYR CA4458 feelfree S...
# 8  y-Free - Onion - WA - - - Need someone to talk...
# 9  Bee Joo (the one squatting down), our staff an...

# %%
# Preprocessing on captions to make them more amenable for analysis, and reliable results. 
# RegEx to remove any punctuation, and then lowercase the text

# Remove punctuation
df['labels_str'] = df['labels_str'].str.replace(r'[^\w\s]', '')

# Convert to lowercase
df['labels_str'] = df['labels_str'].str.lower()

# Replace null values (no caption) with 'null'
df['labels_str'].fillna('null', inplace = True)

# Print out the first rows of papers
df['labels_str'].head()
# Out:
# C:\Users\Draculabites\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   """
# 0    children sv societ caring for the futuro 7a an...
# 1    a day in the life of a youth worker from jyc  ...
# 2     70ml and enterprises 1000 enterprises for chi...
# 3    ente 1000 enterprises for childreninneed child...
# 4
# Name: labels_str, dtype: object

# %% [markdown]
# ### What topics are more related to engagement?

# %% [markdown]
# Create a metric for engagement by using a weighted sum of # likes and # comments.
#
# To create an engagement score, use 0.4# likes (normalized) + 0.6# comments (normalized). Define High (1) and Low (0) engagement based on whether the engagement score is above or below the median value.

# %%
# normalize # likes and # comments such that they both have values between 0 and 1
# scale the # likes by dividing by the maximum # likes (for a post) an # comments

df["likes_normalized"] = df["likeCount"]/df["likeCount"].max() 
df["comments_normalized"] = df["commentCount"]/df["commentCount"].max()

## Create engagement score
df["engagement_score"] = 0.4 * df["likes_normalized"] + 0.6 * df["comments_normalized"]

engagement_median = df["engagement_score"].median()
print(f'median engagement score: {engagement_median}')
df["engagement"] = df["engagement_score"].apply(lambda x: 1 if x > engagement_median else 0)
df.head(3)
# Out:
# median engagement score: 0.029811320754716982
#                                     postUrl  commentCount  likeCount  \
# 0  https://www.instagram.com/p/CbzXkYBsSZ0/             0         12
# 1  https://www.instagram.com/p/CbhK4IQKwcd/             1         36
# 2  https://www.instagram.com/p/CbeksJWrCPZ/             0         46
#
#                                          description  \
# 0  Happy 1st April! This means that… Our Virtual ...
# 1  👀 Take a peep into #adayinthelife of a youth w...
# 2  Singapore Children’s Society held the 1000 Ent...
#
#                                               labels  \
# 0  [Children 'sv, SOCIET, Caring for the Futuro, ...
# 1  [A Day in the, Life of a Youth, Worker From, j...
# 2  [-, 70ml and, ENTERPRISES, 1000 ENTERPRISES FO...
#
#                                           labels_str  likes_normalized  \
# 0  children sv societ caring for the futuro 7a an...          0.022642
# 1  a day in the life of a youth worker from jyc  ...          0.067925
# 2   70ml and enterprises 1000 enterprises for chi...          0.086792
#
#    comments_normalized  engagement_score  engagement
# 0             0.000000          0.009057           0
# 1             0.033333          0.047170           1
# 2             0.000000          0.034717           1

# %%
count = 0
count_li = []
for li in text_all:
    if 'groin' in li or 'sexual' in li:
        count_li.append(count)
    count += 1

count_li
# Out:
# [27,
#  34,
#  407,
#  409,
#  416,
#  581,
#  626,
#  1019,
#  1144,
#  1151,
#  1154,
#  1158,
#  1160,
#  1164,
#  1165]

# %%
print(f'median engagement score: {engagement_median}')
df.iloc[[27, 34, 407, 409, 416, 581, 626, 1019, 1144, 1151, 1154, 1158, 1160, 1164, 1165]].engagement_score
# Out:
# median engagement score: 0.029811320754716982
# 27      0.420000
# 34      0.420000
# 407     0.035094
# 409     0.195849
# 416     0.195849
# 581     0.016604
# 626     0.037358
# 1019    0.021887
# 1144    0.056226
# 1151    0.056226
# 1154    0.026415
# 1158    0.026415
# 1160    0.026415
# 1164    0.066038
# 1165    0.066038
# Name: engagement_score, dtype: float64

# %% [markdown]
# ### Topic modeling (LDA) on the image labels.
#
# Output:
# 1. A file showing which words load on which topics
# 2. A file showing topic weights for each image.
#
# Now take the quartiles with highest and lowest engagement scores. What are the differences in the average topic weights of pictures across the two quartiles (e.g., greater proportion of some topics in highest engagement quartile)? Show the main results in a table.

# %%
# EDA to transfrom caption into inputs for LDA 
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use', 'us', 'like', 'also', 'society', 'societies', 'sgchildren', 
                   'sgchild', 'sgchildrens', 'sgchildrensoc', 'childrens', 'children', 'childs', 'child', 'singapore', 'social', 
                   'youth', 'help', 'support', 'link', 'bio', 'need', 'ms', 'please', 'day', 'today'])

def to_words(sentences):
    for sentence in sentences:
        # deacc = True removes punctuations
        yield(simple_preprocess(str(sentence), deacc=True))

def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word.lower() not in stop_words] for doc in texts]

data_words = list(to_words(list(df['labels_str'])))

# remove stop words
data_words = remove_stopwords(data_words)

print(data_words)
df['tokens'] = data_words
# Out:
# [['sv', 'societ', 'caring', 'futuro', 'smiles', 'hope', 'since', 'virtual', 'flag', 'drop', 'etoken', 'love', 'pass', 'fill', 'bucket', 'full', 'hope', 'virtual', 'flag', 'donate', 'hope', 'sv', 'societ', 'caring', 'futuro', 'smiles', 'hope', 'since', 'virtual', 'flag', 'drop', 'etoken', 'love', 'pass', 'fill', 'bucket', 'full', 'hope', 'virtual', 'flag', 'donate', 'hope'], ['life', 'worker', 'jyc', 'life', 'worker', 'jyc'], ['ml', 'enterprises', 'enterprises', 'childreninneed', 'hope', 'childreninneed', 'lanthropists', 'new', 'philanthropists', 'appreciation', 'ev', 'march', 'inour', 'hean', 'ister', 'curity', 'ml', 'enterprises', 'enterprises', 'childreninneed', 'hope', 'childreninneed', 'lanthropists', 'new', 'philanthropists', 'appreciation', 'ev', 'march', 'inour', 'hean', 'ister', 'curity'], ['ente', 'enterprises', 'childreninneed', 'philanthropists', 'appreciation', 'event', 'march', 'guestofhonour', 'mr', 'teo', 'chee', 'не', 'coordinating', 'min', 'rity', 'ente', 'enterprises', 'childreninneed', 'philanthropists', 'appreciation', 'event', 'march', 'guestofhonour', 'mr', 'teo', 'chee', 'не', 'coordinating', 'min', 'rity'], [], ['enterprises', 'childreninneed', 'enterprises', 'philanthropists', 'appreciation', 'ev', 'arch', 'nour', 'hean', 'ster', 'national', 'security', 'senior', 'enterprises', 'childreninneed', 'enterprises', 'philanthropists', 'appreciation', 'ev', 'arch', 'nour', 'hean', 'ster', 'national', 'security', 'senior'], ['years', 'ozime', 'hope', 'societ', 'canno', 'class', 'br', 'orga', 'years', 'ozime', 'hope', 'societ', 'canno', 'class', 'br', 'orga'], ['make', 'singa', 'every', 'لله', 'ttr', 'tyr', 'ca', 'feelfree', 'samelot', 'camelot', 'make', 'singa', 'every', 'لله', 'ttr', 'tyr', 'ca', 'feelfree', 'samelot', 'camelot'], ['yfree', 'onion', 'wa', 'someone', 'talk', 'speak', 'tinkle', 'friend', 'tus', 'yfree', 'onion', 'wa', 'someone', 'talk', 'speak', 'tinkle', 'friend', 'tus'], ['bee', 'joo', 'one', 'squatting', 'staff', 'volunteer', 'engaging', 'role', 'play', 'training', 'session', 'story', 'hen', 'laid', 'golden', 'eggs', 'choo', 'choo', 'train', 'programme', 'inculcate', 'positive', 'values', 'young', 'story', 'telling', 'role', 'san', 'play', 'tutual', 'skop', 'heart', 'agh', 'ideas', 'bee', 'joo', 'one', 'squatting', 'staff', 'volunteer', 'engaging', 'role', 'play', 'training', 'session', 'story', 'hen', 'laid', 'golden', 'eggs', 'choo', 'choo', 'train', 'programme', 'inculcate', 'positive', 'values', 'young', 'story', 'telling', 'role', 'san', 'play', 'tutual', 'skop', 'heart', 'agh', 'ideas'], ['bee', 'joo', 'gaja', 'one', 'pioneer', 'workers', 'gaja', 'served', 'years', 'retired', 'early', 'bee', 'joo', 'gaja', 'one', 'pioneer', 'workers', 'gaja', 'served', 'years', 'retired', 'early'], ['cabin', 'bee', 'joo', 'conducting', 'training', 'programme', 'cabin', 'club', 'members', 'cabin', 'bee', 'joo', 'conducting', 'training', 'programme', 'cabin', 'club', 'members'], ['thank', 'giving', 'opportunity', 'serve', 'many', 'families', 'past', 'years', 'hope', 'continue', 'grow', 'stay', 'relevant', 'good', 'work', 'many', 'years', 'come', 'thank', 'making', 'difference', 'bee', 'joo', 'thank', 'giving', 'opportunity', 'serve', 'many', 'families', 'past', 'years', 'hope', 'continue', 'grow', 'stay', 'relevant', 'good', 'work', 'many', 'years', 'come', 'thank', 'making', 'difference', 'bee', 'joo'], ['caring', 'future', 'donation', 'donation', 'big', 'small', 'impact', 'lives', 'families', 'caring', 'future', 'donation', 'donation', 'big', 'small', 'impact', 'lives', 'families'], ['caring', 'future', 'donation', 'donation', 'big', 'small', 'impact', 'lives', 'families', 'caring', 'future', 'donation', 'donation', 'big', 'small', 'impact', 'lives', 'families'], ['caring', 'future', 'donation', 'donation', 'big', 'small', 'impact', 'lives', 'families', 'caring', 'future', 'donation', 'donation', 'big', 'small', 'impact', 'lives', 'families'], ['smiles', 'hope', 'caring', 'future', 'since', 'lowincome' ...

# %%
def create_cloud(data):
    text = ','.join(data)

    # Create a WordCloud object
    wordcloud = WordCloud(background_color="black", max_words=5000, contour_width=3, contour_color='steelblue')

    # Generate a word cloud
    wordcloud.generate(text)
    
    return wordcloud

processed = list(itertools.chain(*data_words))

wordcloud = create_cloud(processed)
# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x2348C5DFEB8>

# %%
def bigrams(words, bi_min=15, tri_min=10):
    bigram = gensim.models.Phrases(words, min_count = bi_min)
    bigram_mod = gensim.models.phrases.Phraser(bigram)
    return bigram_mod

def get_corpus(df):
    """
    Get Bigram Model, Corpus, id2word mapping
    """
    bigram = bigrams(df['tokens'])
    bigram = [bigram[review] for review in df['tokens']]
    id2word = gensim.corpora.Dictionary(bigram)
    id2word.filter_extremes(no_below=10, no_above=0.35)
    id2word.compactify()
    corpus = [id2word.doc2bow(text) for text in bigram]
    return corpus, id2word, bigram

train_corpus, train_id2word, bigram_train = get_corpus(df)

# %%
import logging
logging.basicConfig(filename='lda_model.log', format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    lda_train = gensim.models.ldamulticore.LdaMulticore(
                           corpus=train_corpus,
                           num_topics=5,
                           id2word=train_id2word,
                           chunksize=100,
                           workers=7, # Num. Processing Cores - 1
                           passes=50,
                           eval_every = 1,
                           per_word_topics=True)
    lda_train.save('results/topic_modelling_images/lda_train.model')

# %%
coherence_model_lda = CoherenceModel(model=lda_train, texts=bigram_train, dictionary=train_id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print("The coherence of the LDA model is", coherence_lda)
# Out:
# The coherence of the LDA model is 0.3509435333837358

# %%
pprint(lda_train.print_topics())
# Out:
# [(0,
#   '0.097*"future" + 0.074*"societ_caring" + 0.043*"caring_future" + '
#   '0.029*"bullying" + 0.026*"thank" + 0.024*"vox" + 0.023*"love" + '
#   '0.023*"caring" + 0.022*"donation_draw" + 0.022*"dinner"'),
#  (1,
#   '0.099*"caring_future" + 0.050*"happy" + 0.031*"th" + 0.027*"year" + '
#   '0.021*"hope" + 0.020*"good" + 0.020*"tinkle_friend" + 0.019*"one" + '
#   '0.018*"since" + 0.016*"experiences"'),
#  (2,
#   '0.056*"caring_future" + 0.055*"time" + 0.039*"family" + 0.028*"may" + '
#   '0.027*"friends" + 0.025*"school" + 0.022*"home" + 0.021*"pm" + 0.020*"play" '
#   '+ 0.018*"pm_pm"'),
#  (3,
#   '0.069*"caring_future" + 0.025*"dont" + 0.022*"parents" + 0.022*"future" + '
#   '0.018*"food" + 0.017*"tell" + 0.017*"im" + 0.017*"keep" + 0.017*"online" + '
#   '0.016*"give"'),
#  (4,
#   '0.067*"walk" + 0.029*"covid" + 0.026*"de" + 0.025*"free" + 0.023*"mr" + '
#   '0.022*"pm" + 0.022*"event" + 0.020*"caring_future" + 0.020*"join" + '
#   '0.020*"september"')]

# %%
# # Analyzing LDA model results
# # Visualise for interpretability

# # Better understanding and interpreting individual topics
#     # manually select each topic to view its top most frequent and/or “relevant” terms, using different values of the λ parameter. This can help when you’re trying to assign a human interpretable name or “meaning” to each topic.
# # Better understanding the relationships between the topics.
#     # Intertopic Distance Plot can help you learn about how topics relate to each other, including potential higher-level structure between groups of topics.

# # Visualize the topics
# pyLDAvis.enable_notebook()
# LDAvis_data_filepath = os.path.join('./results/topic_modelling/ldavis_prepared_'+ str(num_topics))

# if True:
#     LDAvis_prepared = gensimvis.prepare(lda_model, corpus, id2word)
#     with open(LDAvis_data_filepath, 'wb') as f:
#         pickle.dump(LDAvis_prepared, f)
        
# # load the pre-prepared pyLDAvis data from disk
# with open(LDAvis_data_filepath, 'rb') as f:
#     LDAvis_prepared = pickle.load(f)

# pyLDAvis.save_html(LDAvis_prepared, './results/topic_modelling/ldavis_prepared_'+ str(num_topics) +'.html')

# LDAvis_prepared

vis = gensimvis.prepare(topic_model=lda_train, corpus=train_corpus, dictionary=train_id2word)
pyLDAvis.enable_notebook()
pyLDAvis.display(vis)
# Out:
# C:\Users\Draculabites\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el903624247560067281558551271"></div>
# <script type="text/javascript">
#
# var ldavis_el903624247560067281558551271_data = {"mdsDat": {"x": [0.07008772303727484, -0.16228223051630064, 0.10669984240573617, 0.23314931897151248, -0.24765465389822283], "y": [0.12990464371895716, 0.15850120591304162, 0.08786531081044002, -0.1787491683353517, -0.19752199210708718], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [29.345274379238955, 19.680585666379372, 17.638950091609658, 16.748221986866856, 16.586967875905152]}, "tinfo": {"Term": ["future", "societ_caring", "walk", "time", "happy", "family", "bullying", "dont", "th", "covid", "year", "may", "thank", "de", "pm", "free", "home", "mr", "donation_draw", "vox", "event", "parents", "caring_future", "kindness", "food", "dinner", "tinkle_friend", "friends", "september", "im", "dont", "food", "im", "say", "even", "something", "bullyfree", "someone", "smiles", "body", "teach", "speak", "provide", "safety", "often", "towards", "money", "encourage", "tell", "hand", "hard", "experience", "things", "trusted_adult", "calm", "try", "bringing_hope", "body_safety", "going", "keep", "best", "give", "societ", "friend", "parents", "always", "feel", "change", "information", "online", "every", "caring_future", "think", "skills", "want", "share", "parentips_caring", "years", "find", "future", "know", "would", "talk", "home", "time", "pm_pm", "flag", "loved", "adidas", "games", "jun", "jyc", "christmas", "per", "train", "friday", "choo_choo", "soon", "name", "hello", "available", "fort", "meals", "phone", "set", "play", "family", "members", "contact", "values", "research", "venue", "feeling", "may", "activities", "years_old", "friends", "school", "pm", "make", "caring_future", "date", "better", "hope", "good", "happy", "year", "tinkle_friend", "experiences", "join_th", "caregivers", "makes", "anniversary_conference", "lunar_new", "kind", "adults", "anniversary_nou", "conference_rethinksuccess", "parenting", "rights", "donate", "june", "lecture", "turn", "smiles_hope", "mental_health", "digital", "worker", "th", "giving", "childhood", "board", "life", "ask", "tips", "hope", "caring_future", "since", "together", "one", "good", "see", "people", "lives", "care", "online", "share", "parents", "societ_caring", "bullying", "thank", "donation_draw", "kindness", "sleep", "impact", "lets_come", "together_act", "volunteer", "families", "information_contact", "times", "kindness_mean", "lunch", "meals_breakfast", "physical", "cheryln_ang", "tay_email", "mr_john", "behaviour", "dinner", "rd", "small", "vox", "draw", "heard", "helping", "many", "future", "caring", "love", "person", "care", "media", "caring_future", "stay", "one", "positive", "walk", "de", "free", "mr", "event", "september", "register", "virtual_edition", "november", "education", "national", "minister", "charity", "ministry", "guestofhonour", "stop", "sunday", "july", "hong", "big", "number", "state", "la", "covid", "registration", "service", "bully", "first", "october", "prizes", "join", "community", "saturday", "pm", "caring_future", "challenge"], "Freq": [331.0, 181.0, 163.0, 158.0, 130.0, 126.0, 71.0, 106.0, 88.0, 73.0, 70.0, 99.0, 64.0, 63.0, 118.0, 60.0, 64.0, 55.0, 55.0, 70.0, 52.0, 124.0, 860.0, 52.0, 75.0, 57.0, 51.0, 122.0, 48.0, 73.0, 105.98094378879696, 75.0449084166655, 73.12946987923874, 47.283275318862, 46.17732995664549, 37.5342576407026, 37.19647551416302, 40.34914321980725, 34.41050296649286, 32.232695997495675, 30.100598945720183, 27.75874896515558, 26.741205853845425, 32.363569491807766, 25.86673006286292, 26.275065881843418, 24.70234715385277, 23.777383107097236, 73.55781138075767, 23.56059711727236, 22.863268418444733, 22.112129134246892, 57.482902870780464, 21.800816095247463, 26.47568439604459, 50.72077900874825, 20.018726864896156, 19.941602210020523, 19.144669352819772, 71.387820251892, 45.37993500084369, 66.73608875001626, 45.9395762427981, 31.90373955587523, 95.34578432178293, 34.007943380025445, 63.905611326734906, 36.6635085155932, 41.286482346771, 71.13988841799568, 40.49233801561105 ...

# %%
df_lda = pd.DataFrame(lda_train.show_topics(), columns=['Topic','Word Weights'])
inferred_topics = ["Societal care on bullying", "Caring with Tinkle Friend", "Caring with Family, Friends and School", "Caring from Mainly Parents", "Event/ Programmes"]
rank = [4, 3, 2, 1, 5]
df_lda['Inferred Topics'] = inferred_topics
df_lda['Topic Ranking'] = rank
df_lda.sort_values('Topic Ranking', inplace = True)
df_lda.head()
# Out:
#    Topic                                       Word Weights  \
# 3      3  0.069*"caring_future" + 0.025*"dont" + 0.022*"...
# 2      2  0.056*"caring_future" + 0.055*"time" + 0.039*"...
# 1      1  0.099*"caring_future" + 0.050*"happy" + 0.031*...
# 0      0  0.097*"future" + 0.074*"societ_caring" + 0.043...
# 4      4  0.067*"walk" + 0.029*"covid" + 0.026*"de" + 0....
#
#                           Inferred Topics  Topic Ranking
# 3              Caring from Mainly Parents              1
# 2  Caring with Family, Friends and School              2
# 1               Caring with Tinkle Friend              3
# 0               Societal care on bullying              4
# 4                       Event/ Programmes              5

# %%
df_lda.to_csv('results/topic_modelling_images/Word_Weights_images.csv')

# %%
train_vecs = []
for i in range(len(df['tokens'])):
    # returns the topic distribution for the given document
    top_topics = lda_train.get_document_topics(train_corpus[i], minimum_probability=0.0)
    topic_vec = [top_topics[i][1] for i in range(5)]
    train_vecs.append(topic_vec)
    
print(train_vecs[5])
print(len(train_vecs))
# Out:
# [0.06666736, 0.06666736, 0.06666733, 0.06666726, 0.73333067]
# 1481

# %%
top_topics
# Out:
# [(0, 0.2), (1, 0.2), (2, 0.2), (3, 0.2), (4, 0.2)]

# %%
train_vec_df=pd.DataFrame(train_vecs)
# train_vec_df.columns=['topic0','topic1','topic2','topic3','topic4','topic5','topic6','topic7','topic8','topic9']
train_vec_df.columns=['topic0','topic1','topic2','topic3','topic4']
train_vec_df.iloc[31]
# Out:
# topic0    0.182981
# topic1    0.576804
# topic2    0.222602
# topic3    0.008865
# topic4    0.008748
# Name: 31, dtype: float32

# %%
df_final=pd.concat([df.reset_index(drop=True), train_vec_df.reset_index(drop=True)], axis=1)
df_final.head()
# Out:
#                                     postUrl  commentCount  likeCount  \
# 0  https://www.instagram.com/p/CbzXkYBsSZ0/             0         12
# 1  https://www.instagram.com/p/CbhK4IQKwcd/             1         36
# 2  https://www.instagram.com/p/CbeksJWrCPZ/             0         46
# 3  https://www.instagram.com/p/CbeksJWrCPZ/             0         46
# 4  https://www.instagram.com/p/CbeksJWrCPZ/             0         46
#
#                                          description  \
# 0  Happy 1st April! This means that… Our Virtual ...
# 1  👀 Take a peep into #adayinthelife of a youth w...
# 2  Singapore Children’s Society held the 1000 Ent...
# 3  Singapore Children’s Society held the 1000 Ent...
# 4  Singapore Children’s Society held the 1000 Ent...
#
#                                               labels  \
# 0  [Children 'sv, SOCIET, Caring for the Futuro, ...
# 1  [A Day in the, Life of a Youth, Worker From, j...
# 2  [-, 70ml and, ENTERPRISES, 1000 ENTERPRISES FO...
# 3  [ENTE, 1000 ENTERPRISES FOR CHILDREN-IN-NEED, ...
# 4                                                 []
#
#                                           labels_str  likes_normalized  \
# 0  children sv societ caring for the futuro 7a an...          0.022642
# 1  a day in the life of a youth worker from jyc  ...          0.067925
# 2   70ml and enterprises 1000 enterprises for chi...          0.086792
# 3  ente 1000 enterprises for childreninneed child...          0.086792
# 4                                                             0.086792
#
#    comments_normalized  engagement_score  engagement  \
# 0             0.000000          0.009057           0
# 1             0.033333          0.047170           1
# 2             0.000000          0.034717           1
# 3             0.000000          0.034717           1
# 4             0.000000          0.034717           1
#
#                                               tokens    topic0    topic1  \
# 0  [sv, societ, caring, futuro, smiles, hope, sin...  0.123204  0.384104
# 1             [life, worker, jyc, life, worker, jyc]  0.028572  0.599985
# 2  [ml, enterprises, enterprises, childreninneed,...  0.028954  0.029393
# 3  [ente, enterprises, childreninneed, philanthro...  0.018183  0.018471
# 4                                                 []  0.200000  0.200000
#
#      topic2    topic3    topic4
# 0  0.476517  0.008029  0.008147
# 1  0.314216  0.028625  0.028601
# 2  0.884362  0.028676  0.028615
# 3  0.018887  0.018188  0.926271
# 4  0.200000  0.200000  0.200000

# %%
df_final.to_csv("results/topic_modelling_images/Topic_Weights_images.csv")

# %%
q1=np.percentile(df_final.engagement_score, 25) 
q2=np.percentile(df_final.engagement_score, 50)  
q3=np.percentile(df_final.engagement_score, 75)

print (q1,q2,q3)
# Out:
# 0.018113207547169812 0.029811320754716982 0.046037735849056606

# %%
top_quartile=df_final[df_final['engagement_score']>q3]
top_quartile.head(3)
# Out:
#                                      postUrl  commentCount  likeCount  \
# 1   https://www.instagram.com/p/CbhK4IQKwcd/             1         36
# 9   https://www.instagram.com/p/CbHbKk2rDGb/             1         73
# 10  https://www.instagram.com/p/CbHbKk2rDGb/             1         73
#
#                                           description  \
# 1   👀 Take a peep into #adayinthelife of a youth w...
# 9   It is World Social Work Day today! We invited ...
# 10  It is World Social Work Day today! We invited ...
#
#                                                labels  \
# 1   [A Day in the, Life of a Youth, Worker From, j...
# 9   [Bee Joo (the one squatting down), our staff a...
# 10  [Bee Joo with Ms Gaja, one of Children's Socie...
#
#                                            labels_str  likes_normalized  \
# 1   a day in the life of a youth worker from jyc  ...          0.067925
# 9   bee joo the one squatting down our staff and v...          0.137736
# 10  bee joo with ms gaja one of childrens society ...          0.137736
#
#     comments_normalized  engagement_score  engagement  \
# 1              0.033333          0.047170           1
# 9              0.033333          0.075094           1
# 10             0.033333          0.075094           1
#
#                                                tokens    topic0    topic1  \
# 1              [life, worker, jyc, life, worker, jyc]  0.028572  0.599985
# 9   [bee, joo, one, squatting, staff, volunteer, e...  0.377085  0.101599
# 10  [bee, joo, gaja, one, pioneer, workers, gaja, ...  0.837237  0.041043
#
#       topic2    topic3    topic4
# 1   0.314216  0.028625  0.028601
# 9   0.507340  0.007005  0.006972
# 10  0.040475  0.041095  0.040150

# %%
average_topic_weights_top = top_quartile[["topic0",'topic1',"topic2",'topic3',"topic4"]].mean(axis=0)
average_topic_weights_top
# Out:
# topic0    0.189323
# topic1    0.173284
# topic2    0.187560
# topic3    0.289824
# topic4    0.160010
# dtype: float32

# %%
bottom_quartile=df_final[df_final['engagement_score']<q1]
bottom_quartile.head(3)
# Out:
#                                      postUrl  commentCount  likeCount  \
# 0   https://www.instagram.com/p/CbzXkYBsSZ0/             0         12
# 16  https://www.instagram.com/p/Caoe0jUsfQh/             0         14
# 17  https://www.instagram.com/p/Cal6BHIPdm7/             0          7
#
#                                           description  \
# 0   Happy 1st April! This means that… Our Virtual ...
# 16  Food insecurity refers to a state where one la...
# 17  What do you do when you suspect that child abu...
#
#                                                labels  \
# 0   [Children 'sv, SOCIET, Caring for the Futuro, ...
# 16  [Children's, SOCIETY, 70 smiles, and hope, Car...
# 17  [Children S, SOCIETY, Caring for the Future, 7...
#
#                                            labels_str  likes_normalized  \
# 0   children sv societ caring for the futuro 7a an...          0.022642
# 16  childrens society 70 smiles and hope caring fo...          0.026415
# 17  children s society caring for the future 70 ho...          0.013208
#
#     comments_normalized  engagement_score  engagement  \
# 0                   0.0          0.009057           0
# 16                  0.0          0.010566           0
# 17                  0.0          0.005283           0
#
#                                                tokens    topic0    topic1  \
# 0   [sv, societ, caring, futuro, smiles, hope, sin...  0.123204  0.384104
# 16  [smiles, hope, caring, future, since, lowincom...  0.018234  0.412121
# 17  [caring, future, hope, smiles, since, decision...  0.018242  0.690181
#
#       topic2    topic3    topic4
# 0   0.476517  0.008029  0.008147
# 16  0.018250  0.533166  0.018229
# 17  0.018327  0.255028  0.018221

# %%
average_topic_weights_bot = bottom_quartile[["topic0",'topic1',"topic2",'topic3',"topic4"]].mean(axis=0)
average_topic_weights_bot
# Out:
# topic0    0.186323
# topic1    0.232318
# topic2    0.198072
# topic3    0.202718
# topic4    0.180569
# dtype: float32

# %%
quartile_topics = pd.concat([average_topic_weights_top,average_topic_weights_bot],axis=1)
quartile_topics.columns = ['Top Quartile','Bottom Quartile']
quartile_topics
# Out:
#         Top Quartile  Bottom Quartile
# topic0      0.189323         0.186323
# topic1      0.173284         0.232318
# topic2      0.187560         0.198072
# topic3      0.289824         0.202718
# topic4      0.160010         0.180569

# %%
difference = (quartile_topics['Bottom Quartile'] - quartile_topics['Top Quartile'])/ quartile_topics['Top Quartile'] * 100
diff = [str(round(d, 3)) for d in list(abs(difference))]
quartile_topics['% difference'] = diff
quartile_topics['Inferred Topics'] = inferred_topics
quartile_topics['Ranking Topics'] = rank
quartile_topics
# Out:
#         Top Quartile  Bottom Quartile % difference  \
# topic0      0.189323         0.186323        1.585
# topic1      0.173284         0.232318       34.068
# topic2      0.187560         0.198072        5.604
# topic3      0.289824         0.202718       30.055
# topic4      0.160010         0.180569       12.849
#
#                                Inferred Topics  Ranking Topics
# topic0               Societal care on bullying               4
# topic1               Caring with Tinkle Friend               3
# topic2  Caring with Family, Friends and School               2
# topic3              Caring from Mainly Parents               1
# topic4                       Event/ Programmes               5
