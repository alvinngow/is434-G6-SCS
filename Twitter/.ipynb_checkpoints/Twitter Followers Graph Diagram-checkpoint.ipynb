# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import csv
import pandas as pd
import matplotlib
from matplotlib.pyplot import figure, text

# %%
df = pd.read_csv('Twitter/twitter_followers_followers.csv')
carac = pd.read_excel('Twitter/twitter_followers_types.xlsx')

# %%
Graphtype = nx.Graph()
G = nx.from_pandas_edgelist(df, source='source', target='target', create_using=nx.DiGraph())
G.nodes()
# Out:
# NodeView(('Sumi_Thomas_', 'sgchildrensoc', 'Films_ForAll', 'Elena_96669', 'gimeunhye121', 'haroldoborralho', 'hngzhanpeng', 'PRADIPK16060930', 'CRCAsia', 's_u_n_j_a_y', 'LUV_YLD', 'JBJeyaretnam', 'ishu_rp', 'quickhrsg', 'Anindya72727262', 'HoiShan_Cheung', 'elinorlim_', 'KampungBoii', 'zira99722724', 'Carlo48430919', 'CosmosSejal', 'sembian_siva', 'Digital247_', 'Mariebiscuitty', 'Sumi_musings', 'TikTokForGood', 'AngelicaPE_SE', 'icqpickup', 'JOSEPHI86107217', 'ClarisseChristi', 'MdAbidu59298192', 'gftrinidad19', 'CherylChuaBLzzz', 'Leojia813', 'liezlctan', 'a4anga', 'saffronsgpore', 'LNumerist', 'Eunice_Alison', 'FAmbientalBR', 'CodeLearnng', 'sgbenchua', 'cjsprincess', 'ktk_1415', 'jwlteng', 'verified', 'WeeYeh_Tow', 'CHAOYUEHE', 'STEPHENKILEL', 'AceWork5', 'ISPCAN', 'ABCDEK4', 'Denzel25373494', 'aqb589', 'DHYANAAROGYAM', 'oswinsteve', 'munyee998882', 'BreegiSci', 'KeriMcCrickerd', 'rachelfc', 'ArtlayStudio', 'marlina_tay', 'EdsFinadviser', 'ckelly_law', 'carnagecaesar', 'kcreizxschya', 'leonardtangty', 'irrational_ling', 'MikeGoh96', 'sivaGofficial', 'larry_olp', '926_kate', 'Jaynetoh', 'yensim2', 'santhanaram', 'MBIMB1', 'darisjob25', 'ayuremie', 'SDEAofficial', 'ginlwc', 'FreddyHuat', 'wwceline', 'AnnieSoh2', 'Omnipotemtem', 'Cross_E98', 'chirowena', 'jkh2016', 'thinkerbellej', 'captioncube', 'thia_la', 'tohzhiyangrv', 'ShaniaChia', 'My_Bartender_SG', 'Freedom_Fusion', 'Emerald_6804_', 'DaveOng93', 'junweihor', 'mohdkhair66', 'ChefSaiful1', 'HashAnand', 'evng_mehtab', 'RoniMolla9', 'xiefax', 'WY8D', 'Ernieloh', 'shisha_music', 'bloggershop1', 'PayalPisal', 'nanacabana', 'pohyoke84', 'quixiequint', 'jacksontanera', 'himeyaalan', 'bhfxtraining', 'ViperxIrfan', 'MithleshR0801', 'MdNuruzzamanRo3', 'kathieloh78', 'gohpg251309', 'CrystalLimMing1', 'JAYDEEPMACHHI2', 'Lucky_Dragon747', 'HMM_VIRGO', '_DCALS', 'acky3000', 'AloysiuChen', 'cheetahbubbles', 'Koala_Sd', 'irene30277', 'SalesCheng', 'anokhi_san', 'ahsun0903', 'doverotter', '861d560f9d37409', 'YukieTan_XH', 'tkwees', 'sng_pc', 'sexilycandid', 'yx_ng', '38details', 'projectkindle_', 'littleslowly', 'azmierango', 'arirang533', 'reshmysudeep', 'SophieLinke', 'zhibin87', 'strivestudiossg', 'DaleHamid', 'patricksia2004', 'mayawehbi8', 'doodleolio', 'sMiLiNgDaz', 'SonakshiS11', 'LibeInnovation', 'salusalmanmgm', 'Bitcoinsvj', 'mcs_mss', 'ClintoneBill', 'Lucifer_1123', 'feelinggroovy', 'vermicelliapple', 'MacrinePhD', 'Experimentsinfc', 'jonhonay', 'Prince_Madness1', 'NielsKeira', 'TJHuntley', 'leenasind', 'NTU_English', 'FreelanceOwl', 'DASimpsonpoet', 'kaleidopathic', 'MdIkbal06549795', 'drsurendrpathak', 'MrSamyaMitra', 'chessforumnyc', 'Rari21637701', 'Ravinde66613416', 'stephenkelley85', 'kvnrrdn', 'ravanatalks', 'Melodie_Ramone', 'whocareswho_Iam', 'nellor_dan', 'babymuse25', 'wordketcircle', 'jbubjr', 'DamianDonWilli4', 'tveitdal', 'MarciaLynnPaul1', 'Tania76690323', 'StephenRoth316', 'ConyersThe', 'MasterJi_UPwale', 'grantburt', 'DTNEtiquette', 'MarionBerndt', 'isalittlebrok3n', 'TheUHMethod', 'Enigma68701983', 'PoeticEsther', 'Upasika1', 'FathimaSantiago', 'Debbyk65', 'Vulcans14', 'WriteCIub', 'NixonJoseph1708', 'darkxfer', 'TheVintner', 'AnsonLiverio', 'andylectablyme', 'sfmnu', 'Parma2mbn', 'MyPascual28', 'iam_united_', 'ayyapanmusings', 'Rajeev_s10', 'BrahmandSundari', 'SarcasticCowboy', 'AnonyMallu', 'manvalism', 'truemalayali', 'BeeranKutty123', 'extraemotion_', 'hindustanukk', 'psychomaaman', 'thatwaywardboy', 'Mahesh_abc', 'Mr_Kaappi_Guru', 'mentabolism', 'Deepakof78', 'sunilbibekar', 'Prakash_Joseph', 'porottaANDbeef', 'joyson_93', 'pcrini_M', 'thomasJins', 'MisterRustic', 'lib_eratus', 'jubinkv', 'mathewcbabraham', 'riofoundation', 'Lisa_Stepanovic', 'yucan_cic', 'SocialArkCIO', 'tdh_ch', 'xconversationuk', 'LondonYouth', 'IICFStrath', 'CovidUnder19', 'TrowsdaleGary', 'jonoheffernan', '2020ChangeUk', 'esol_ni', 'abbee_NYA', 'SupportAgenda', 'BronaghByrneQUB', 'womenstrongintl', 'PrathitSingh1', 'MTempletonQUB', 'Stephan09424667', 'Art2StartNW', 'LerchVeronique' ...

# %%
# Make types into categories
carac = carac.set_index('source')
carac = carac.reindex(G.nodes())
carac['type']=pd.Categorical(carac['type'])
carac['type'].cat.codes
# Out:
# source
# Sumi_Thomas_       1
# sgchildrensoc     -1
# Films_ForAll       1
# Elena_96669        1
# gimeunhye121       1
#                   ..
# GiangVNht2         0
# MunayTaty          0
# NdivoJustus        0
# Melanie14109971    0
# JulieneSousa18     0
# Length: 9638, dtype: int8

# %%
# Specify colors
cmap = matplotlib.colors.ListedColormap(['blue', 'darkorange', "green"])

# %%
# Node Degrees
d = nx.degree(G)
degree_values = [v * 50 for k, v in d]

# font sizes
d = dict(G.degree)
pos = nx.spring_layout(G)

# %%
plt.figure(figsize = (20,20))
nx.draw(G, with_labels=True, pos=pos, node_size=degree_values, node_color=carac['type'].cat.codes, cmap=cmap)
for node, (x, y) in pos.items():
    text(x, y, node, fontsize=d[node]*0.05, ha='center', va='center')  
plt.show()

# %%
plt.figure(figsize = (20,20))
nx.draw(G, with_labels=True, node_size=degree_values, node_color=carac['type'].cat.codes, font_size=10, cmap=cmap)
plt.show()

# %%
edge_list = list(G.edges())

total_num_edges = 0
all_edges = []
reciprocating_edges = []
for (source, target) in edge_list:
    if (str(source) + "<->" + str(target)) not in reciprocating_edges:
        total_num_edges += 1
        all_edges.append(str(source) + "-" + str(target))
        
        if G.has_edge(target, source):
            print("=========== Nodes ", source, "and", target, " have a bi-directional/reciprocal edge =========")
            reciprocating_edges.append( str(target) + "<->" + str(source) )

print("\nTotal number of edges: ", total_num_edges)
# print(all_edges)
print("\nTotal number of 'reciprocating' edges: ", len(reciprocating_edges))
print(reciprocating_edges)

network_reciprocity = len(reciprocating_edges) / len(all_edges)
print("\nNetwork-level Reciprocity: %.3f" % network_reciprocity)
# Out:
# =========== Nodes  Sumi_Thomas_ and Anindya72727262  have a bi-directional/reciprocal edge =========
# =========== Nodes  HoiShan_Cheung and elinorlim_  have a bi-directional/reciprocal edge =========
#
# Total number of edges:  9717
#
# Total number of 'reciprocating' edges:  2
# ['Anindya72727262<->Sumi_Thomas_', 'elinorlim_<->HoiShan_Cheung']
#
# Network-level Reciprocity: 0.000

# %%
nx.write_gexf(G, "twitter_followers.gexf")

# %%
from fa2 import ForceAtlas2
forceatlas2 = ForceAtlas2(
                        # Behavior alternatives
                        outboundAttractionDistribution=True,  # Dissuade hubs
                        linLogMode=False,  # NOT IMPLEMENTED
                        adjustSizes=False,  # Prevent overlap (NOT IMPLEMENTED)
                        edgeWeightInfluence=1.0,

                        # Performance
                        jitterTolerance=1.0,  # Tolerance
                        barnesHutOptimize=True,
                        barnesHutTheta=1.2,
                        multiThreaded=False,  # NOT IMPLEMENTED

                        # Tuning
                        scalingRatio=2.0,
                        strongGravityMode=False,
                        gravity=1.0,

                        # Log
                        verbose=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 from fa2 import ForceAtlas2
#       2 forceatlas2 = ForceAtlas2(
#       3                         # Behavior alternatives
#       4                         outboundAttractionDistribution=True,  # Dissuade hubs
#    (...)
#      20                         # Log
#      21                         verbose=True)
#
# ModuleNotFoundError: No module named 'fa2'
