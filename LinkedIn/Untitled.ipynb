# %%
import nltk

nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 import nltk
# ----> 3 nltk.download()
#
# File ~\anaconda3\lib\site-packages\nltk\downloader.py:763, in Downloader.download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to)
#     761     if download_dir is not None:
#     762         self._download_dir = download_dir
# --> 763     self._interactive_download()
#     764     return True
#     766 else:
#     767     # Define a helper function for displaying output:
#
# File ~\anaconda3\lib\site-packages\nltk\downloader.py:1113, in Downloader._interactive_download(self)
#    1111 if TKINTER:
#    1112     try:
# -> 1113         DownloaderGUI(self).mainloop()
#    1114     except TclError:
# ...

# %%
import pandas as pd

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ailys\AppData\Roaming\nltk_data...
# True

# %%
# import .csv
df = pd.read_csv("scs linkedin posts.csv")
df.head()
# Out:
#                                              postUrl  \
# 0  https://www.linkedin.com/feed/update/urn:li:ac...
# 1  https://www.linkedin.com/feed/update/urn:li:ac...
# 2  https://www.linkedin.com/feed/update/urn:li:ac...
# 3  https://www.linkedin.com/feed/update/urn:li:ac...
# 4  https://www.linkedin.com/feed/update/urn:li:ac...
#
#                                           companyUrl  \
# 0  https://www.linkedin.com/company/singapore-chi...
# 1  https://www.linkedin.com/company/singapore-chi...
# 2  https://www.linkedin.com/company/singapore-chi...
# 3  https://www.linkedin.com/company/singapore-chi...
# 4  https://www.linkedin.com/company/singapore-chi...
#
#                     companyName   followerCount postDate  duration  \
# 0  Singapore Children's Society  1.5K followers       5d         5
# 1  Singapore Children's Society  1.5K followers       2w         2
# 2  Singapore Children's Society  1.5K followers       1w         1
# ...

# %%
df["neg"] = int()
df["neu"] = int()
df["pos"] = int()
df["compound"] = int()

# %%
df
# Out:
#                                                postUrl  \
# 0    https://www.linkedin.com/feed/update/urn:li:ac...
# 1    https://www.linkedin.com/feed/update/urn:li:ac...
# 2    https://www.linkedin.com/feed/update/urn:li:ac...
# 3    https://www.linkedin.com/feed/update/urn:li:ac...
# 4    https://www.linkedin.com/feed/update/urn:li:ac...
# ..                                                 ...
# 118  https://www.linkedin.com/feed/update/urn:li:ac...
# 119  https://www.linkedin.com/feed/update/urn:li:ac...
# 120  https://www.linkedin.com/feed/update/urn:li:ac...
# 121  https://www.linkedin.com/feed/update/urn:li:ac...
# 122  https://www.linkedin.com/feed/update/urn:li:ac...
#
#                                             companyUrl  \
# 0    https://www.linkedin.com/company/singapore-chi...
# 1    https://www.linkedin.com/company/singapore-chi...
# 2    https://www.linkedin.com/company/singapore-chi...
# 3    https://www.linkedin.com/company/singapore-chi...
# ...

# %%
# append sentiment analysis data to df
for idx, row in df.iterrows():
    sia.polarity_scores("Wow, NLTK is really powerful!")
#     df.loc[idx].at["neg"] = sia.polarity_scores(row["textContent"])["neg"]
#     df.loc[idx].at["pos"] = sia.polarity_scores(row["textContent"])["pos"]
#     df.loc[idx].at["neu"] = sia.polarity_scores(row["textContent"])["neu"]
#     df.loc[idx].at["compound"] = sia.polarity_scores(row["textContent"])["compound"]
    df.at[idx, "neg"] = sia.polarity_scores(row["textContent"])["neg"]
    df.at[idx, "pos"] = sia.polarity_scores(row["textContent"])["pos"]
    df.at[idx, "neu"] = sia.polarity_scores(row["textContent"])["neu"]
    df.at[idx, "compound"] = sia.polarity_scores(row["textContent"])["compound"]

# %%
df.head()
# Out:
#                                              postUrl  \
# 0  https://www.linkedin.com/feed/update/urn:li:ac...
# 1  https://www.linkedin.com/feed/update/urn:li:ac...
# 2  https://www.linkedin.com/feed/update/urn:li:ac...
# 3  https://www.linkedin.com/feed/update/urn:li:ac...
# 4  https://www.linkedin.com/feed/update/urn:li:ac...
#
#                                           companyUrl  \
# 0  https://www.linkedin.com/company/singapore-chi...
# 1  https://www.linkedin.com/company/singapore-chi...
# 2  https://www.linkedin.com/company/singapore-chi...
# 3  https://www.linkedin.com/company/singapore-chi...
# 4  https://www.linkedin.com/company/singapore-chi...
#
#                     companyName   followerCount postDate  duration  \
# 0  Singapore Children's Society  1.5K followers       5d         5
# 1  Singapore Children's Society  1.5K followers       2w         2
# 2  Singapore Children's Society  1.5K followers       1w         1
# ...

# %%
# Average Scores
mean_neu = df["neu"].mean()
mean_neg = df["neg"].mean()
mean_pos = df["pos"].mean()
mean_compound = df["compound"].mean()
print(f"Average Negative Score: {mean_neg:.3f}")
print(f"Average Neutral Score: {mean_neu:.3f}")
print(f"Average Positive Score: {mean_pos:.3f}")
print(f"Average Compound Score: {mean_compound:.3f}")
# Out:
# Average Negative Score: 0.023
# Average Neutral Score: 0.782
# Average Positive Score: 0.195
# Average Compound Score: 0.747

# %%
df.sort_values("likeCount", axis=0, ascending=False).head(10)
# Out:
#                                               postUrl  \
# 19  https://www.linkedin.com/feed/update/urn:li:ac...
# 17  https://www.linkedin.com/feed/update/urn:li:ac...
# 16  https://www.linkedin.com/feed/update/urn:li:ac...
# 1   https://www.linkedin.com/feed/update/urn:li:ac...
# 5   https://www.linkedin.com/feed/update/urn:li:ac...
# 12  https://www.linkedin.com/feed/update/urn:li:ac...
# 11  https://www.linkedin.com/feed/update/urn:li:ac...
# 18  https://www.linkedin.com/feed/update/urn:li:ac...
# 9   https://www.linkedin.com/feed/update/urn:li:ac...
# 31  https://www.linkedin.com/feed/update/urn:li:ac...
#
#                                            companyUrl  \
# 19  https://www.linkedin.com/company/singapore-chi...
# 17  https://www.linkedin.com/company/singapore-chi...
# 16  https://www.linkedin.com/company/singapore-chi...
# 1   https://www.linkedin.com/company/singapore-chi...
# 5   https://www.linkedin.com/company/singapore-chi...
# ...

# %%
df.sort_values("likeCount", axis=0, ascending=False).tail(10).mean()
# Out:
# C:\Users\ailys\AppData\Local\Temp\ipykernel_23296\4278637851.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.sort_values("likeCount", axis=0, ascending=False).tail(10).mean()
# duration          6.600000
# numOfDays       189.600000
# likeCount         1.833333
# commentCount      0.000000
# neg               0.010700
# neu               0.776000
# pos               0.213200
# compound          0.757120
# dtype: float64

# %%
df.sort_values("likeCount", axis=0, ascending=False).head(10).mean()
# Out:
# C:\Users\ailys\AppData\Local\Temp\ipykernel_23296\1325739304.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.sort_values("likeCount", axis=0, ascending=False).head(10).mean()
# duration          3.60000
# numOfDays       173.60000
# likeCount        31.50000
# commentCount      0.80000
# neg               0.02030
# neu               0.78930
# pos               0.19040
# compound          0.88562
# dtype: float64

# %%
print(f"{df["neu"].mean().astype(str)}")
# Out:
#   Input In [58]
#     print(f"{df["neu"].mean().astype(str)}")
#                  ^
# SyntaxError: f-string: unmatched '['
